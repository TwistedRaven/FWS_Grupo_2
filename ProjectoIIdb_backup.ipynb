# %%
# Entrega II cadeira Web-semantica @ Fcul 2020-2021
# Realizado por João Pinto(55018) e Ricardo Meireles(55841) 

#TODO LIST
#Use known vocabularies (e.g. FOAF, vCard, DC, schema.org) for expressing entities - DONE
#Enrich their triplestore with external data from whatever source (e.g. dbpedia, wikidata, worldbank linked data, ...) - DONE
#Define the RDFS and RDFS+ rules for allowing inferred queries through a reasoner - 1/2

# %%
import csv
import rdflib
import re
from rdflib import Graph, Literal, Namespace, URIRef, BNode
from rdflib.plugins.sparql import prepareQuery
from rdflib.namespace import DCTERMS, RDF, RDFS, XSD
from urllib.parse import quote
from SPARQLWrapper import SPARQLWrapper, XML, TSV, POST, DIGEST, JSON
from string import Template


ListaEquipas = ["Equipa"]

NFL = Namespace('http://www.nfl.com/')
pff = Namespace('http://www.pff.com/')

Schema = Namespace("http://schema.org/")
Schema.Person = rdflib.term.URIRef(u'http://schema.org/Person')
Schema.City = rdflib.term.URIRef(u'http://schema.org/City')
Schema.SportsTeam = rdflib.term.URIRef(u'http://schema.org/SportsTeam')
Schema.Athlete = rdflib.term.URIRef(u'http://schema.org/athlete')
Schema.CollegeOrUniversity = rdflib.term.URIRef(u'http://schema.org/CollegeOrUniversity')

statid=1

dados_equipas = csv.DictReader(open("nfl_teams.csv"))
dados_base = csv.DictReader(open("Basic_Stats_Sample.csv"))
dados_passing = csv.DictReader(open("Career_Stats_Passing_Sample.csv"))


dados = Graph()

# %%
for row in dados_equipas:
    idequipa =row['ID']
    nomeequipa = row ['Name']
    equipa=URIRef(NFL+idequipa)
    
    ListaEquipas.append(nomeequipa)

    dados.add((equipa, RDF.type, Schema.SportsTeam))
    dados.add((equipa, RDFS.label, Literal(nomeequipa,lang="en")))
    dados.add((equipa,Schema.name,Literal(nomeequipa)))
    dados.add((equipa,Schema.sport,Literal("American Football")))
    
    
    sparql = SPARQLWrapper("http://dbpedia.org/sparql")
    sparql.addDefaultGraph("http://dbpedia.org")
    query =Template( """
    PREFIX dbpedia: <http://dbpedia.org/resource/> 
    Select ?team ?coach ?owner ?fd ?sb ?abs
     WHERE{ 
        # ?team rdfs:label "$nome_equipa"@en;
        dbo:coach ?coach;
        dbo:owner ?owner;
        dbo:formationDate ?fd;
        dbp:noSbChamps ?sb;
        dbo:abstract ?abs.
        FILTER (lang(?abs) = 'en')
    }
        LIMIT 1
    """)


    sparql.setQuery(query.substitute(nome_equipa=nomeequipa))
    sparql.setReturnFormat(JSON)
    results = sparql.query().convert()

    #print(results)

    for result in results["results"]["bindings"]:
     if (str(result["coach"]["value"])):
      coach = str(result["coach"]["value"]) 
      owner = str(result["owner"]["value"])
      abs = str(result["abs"]["value"])
      fd = str(result["fd"]["value"])
      sb = int(result["sb"]["value"])   
      dados.add((equipa, Schema.coach, URIRef(coach)))
      dados.add((equipa, Schema.owner, URIRef(owner)))
      dados.add((equipa, Schema.noSbChamps, Literal(sb,datatype=XSD.int)))
      dados.add((equipa, Schema.abstract, Literal(abs))) 
      dados.add((equipa, Schema.formationDate, Literal(fd,datatype=XSD.date)))
    
    
    
    
    
    #sparql.setQuery(query.substitute(nome_equipa=nomeequipa))
    #sparql.setReturnFormat(JSON)
    #results = sparql.query().convert()

    
    #for result in results["results"]["bindings"]:
     #if (str(result["coach"]["value"])):
      #coach = str(result["coach"]["value"]) 
      #owner = str(result["owner"]["value"])
      #abs = str(result["abs"]["value"]) 
      #fd = str(result["fd"]["value"])
      #sb = int(result["sb"]["value"])   
    
        
    #dados.add((equipa,Schema.coach,URIRef(coach)))
    #dados.add((equipa,Schema.owner,URIRef(owner)))
    #dados.add((equipa,Schema.noSbChamps ,Literal(sb,datatype=XSD.int)))  
    #dados.add((equipa,Schema.abstract  ,Literal(abs))) 
    #dados.add((equipa,Schema.formationDate  ,Literal(fd,datatype=XSD.date)))

# %%
for row in dados_base:
    
    id =row['Player Id'] 

    current_team = row['Current Team']

    name = Literal(row['Name'])
    position = Literal(row['Position'])
    player_number = Literal(row['Number'],datatype=XSD.int)
    current_status = Literal(row['Current Status'])
    experience = Literal(row['Experience'])
    birth_place = row['Birth Place']
    birth_day = Literal(row['Birthday'],datatype=XSD.date)
    college = Literal(row['College'])
    high_school = Literal(row['High School'])
    height = Literal(row['Height (inches)'],datatype=XSD.int)
    weight = Literal(row['Weight (lbs)'],datatype=XSD.int)
    year_played = Literal(row['Years Played'])

    #tratamento do player para tirar o nome ao id e addicionar como person e atleta
    
    string_player = str(id)
    player = URIRef(NFL+string_player.split('/')[1])

    dados.add((player, RDF.type, Schema.Person))
    dados.add((player, RDF.type, Schema.Athlete))
    
    dados.add((player, Schema.Gender,  URIRef("http://schema.org/Male") ))

    
    #addicionar birthday ao schema
    dados.add((player,Schema.birthDate,birth_day))

    # Tratamento do campo name, separar por nome e nome de familia e addicionar o triplo com o schema
    string_name = str(name)
    dados.add((player, Schema.givenName, Literal(string_name.split(',')[1] )))  
    dados.add((player, Schema.familyName, Literal(string_name.split(',')[0] )))  
    
    # Tratamento do years played, separar por temporada e addicionar todas ao triplo
    string_years = str(year_played)
    if  string_years:  
     nums = [int(n) for n in string_years.split('-')] 
    x = range(nums[0], nums[1]+1)
    for n in x: 
     dados.add((player, NFL.yearPlayed, Literal(n,datatype=XSD.int)))  

    # Addicionar jogador como atlete do schema Sports Team
    if current_team:  
      dados.add((URIRef(NFL+str(ListaEquipas.index(current_team))),Schema.atlete,player))  
    
    #tratar a experience e addicionar ao schema
    
    string_exp = row['Experience']
    if string_exp:
     temp = re.findall(r'\d+', string_exp) 
     res = list(map(int, temp)) 
     dados.add((player, NFL.experience, Literal(res[0],datatype=XSD.int)))
    
    #Tratamento do campo Birthplace, retirar estado e addicionar o triplo com o schema
    if birth_place: 
     string_birth = str(birth_place)
     dados.add((player, Schema.birthPlace, Literal(string_birth.split(',')[0] ))) 
        
    dados.add((player, NFL.currentStatus, current_status)) #addicionar current status
    
    dados.add((player, NFL.college, college)) #addicionar college
    
    #addicionar Hight and Weight
    dados.add((player, Schema.height, height))
    dados.add((player, Schema.weight, weight))
    
    if position:   #addicionar posiçao se existir no ficheiro
        dados.add((player, NFL.position, position))
    if player_number:  #addicionar numero do jogador se existir no ficheiro
        dados.add((player, NFL.playerNumber, player_number))
        
    if high_school: #tratamento de high school (retirar o hs) e addicionar ao triploe
        hs_string = high_school
        dados.add((player, NFL.highSchool, Literal(hs_string.split('HS')[0]))) 
        
    dados.add((player, RDFS.label, Literal(nomeequipa,lang="en")))    
        

    #-------------------------------------------------------------------------------------------------------------------------------
    #Definições de RDFS e RDFS+
    # Define the RDFS and RDFS+ rules for allowing inferred queries through a reasoner
        
        
    #dados.add((player, RDFS.domain, ))
        
    #Primeiro em termos leigos:
    #tal como G.add((X.Vehicle, RDFS.subClassOf, X.Machine))
    #Então
    #dados.add(())

# %%
for row in dados_passing:
      
     id =row['Player Id'] 
    
     player = URIRef(NFL+id)

     year = Literal(row['Year'])
     
     playerseason= URIRef(NFL+id+"/"+quote(row['Year']))
    
     name = URIRef(NFL+quote(row['Name']))
     team = URIRef(NFL+quote(row['Team']))
     games_played = Literal(row['Games Played'])
     passes_attempted = Literal(row['Passes Attempted'])
     passes_completed = Literal(row['Passes Completed'])
     completion_percentage = Literal(row['Completion Percentage'])
     pass_att_per_game = Literal(row['Pass Attempts Per Game'])
     passing_yards = Literal(row['Passing Yards'])
    
     passing_yards_att = Literal(row['Passing Yards Per Attempt'])
     passing_yards_game = Literal(row['Passing Yards Per Game'])
     td_passes = Literal(row['TD Passes'])
     percentage_tds_per_attemp = Literal(row['Percentage of TDs per Attempts'])
    
     interceptions = Literal(row['Ints'])
     interceptions_rate = Literal(row['Ints'])
     longest_pass = Literal(row['Longest Pass'])
     passes_longer_20yards = Literal(row['Passes Longer than 20 Yards'])
    
     passes_longer_40yards = Literal(row['Passes Longer than 40 Yards'])
     sacks = Literal(row['Sacks'])
     sacked_yards_lost = Literal(row['Sacked Yards Lost'])
     passer_rating = Literal(row['Passer Rating'])
  

     dados.add((playerseason, RDF.type, NFL.playerseason))
     dados.add((playerseason, RDFS.label, Literal(year, lang="en")))

     dados.add((player, NFL.playerseason, playerseason))

     dados.add((playerseason,NFL.team,team))
     dados.add((playerseason,NFL.games_played,games_played))
     dados.add((playerseason,NFL.passes_attempted,passes_attempted))
     dados.add((playerseason,NFL.passes_completed,passes_completed))
     dados.add((playerseason,NFL.completion_percentage,completion_percentage))
     dados.add((playerseason,NFL.pass_att_per_game,pass_att_per_game))
     dados.add((playerseason,NFL.passing_yards,passing_yards))
    
     dados.add((playerseason,NFL.passing_yards_att,passing_yards_att))
     dados.add((playerseason,NFL.passing_yards_game,passing_yards_game))
     dados.add((playerseason,NFL.td_passes,td_passes))
     dados.add((playerseason,NFL.percentage_tds_per_attemp,percentage_tds_per_attemp))
    
     dados.add((playerseason,NFL.interceptions,interceptions))
     dados.add((playerseason,NFL.interceptions_rate,interceptions_rate))
     dados.add((playerseason,NFL.longest_pass,longest_pass))
     dados.add((playerseason,NFL.passes_longer_20yards,passes_longer_20yards))
    
     dados.add((playerseason,NFL.passes_longer_40yards,passes_longer_40yards))
     dados.add((playerseason,NFL.sacks,sacks))
     dados.add((playerseason,NFL.sacked_yards_lost,sacked_yards_lost))
     dados.add((playerseason,NFL.passer_rating,passer_rating))
    
     dados.add((playerseason, NFL.name, name ))  
     dados.add((playerseason, NFL.year, year ))  

             
     #dados.add((player, NFL.player_stat, player_stat ))  
     #dados.add((player_stat, year, stat_year ))
    
     #dados.add((stat_year,NFL.team,team))
     #dados.add((stat_year,NFL.games_played,games_played))
     #dados.add((stat_year,NFL.passes_attempted,passes_attempted))
     #dados.add((stat_year,NFL.passes_completed,passes_completed))
     #dados.add((stat_year,NFL.completion_percentage,completion_percentage))
     #dados.add((stat_year,NFL.pass_att_per_game,pass_att_per_game))
     #dados.add((stat_year,NFL.passing_yards,passing_yards))
    
     #dados.add((stat_year,NFL.passing_yards_att,passing_yards_att))
     #dados.add((stat_year,NFL.passing_yards_game,passing_yards_game))
     #dados.add((stat_year,NFL.td_passes,td_passes))
     #dados.add((stat_year,NFL.percentage_tds_per_attemp,percentage_tds_per_attemp))
    
     #dados.add((stat_year,NFL.interceptions,interceptions))
     #dados.add((stat_year,NFL.interceptions_rate,interceptions_rate))
     #dados.add((stat_year,NFL.longest_pass,longest_pass))
     #dados.add((stat_year,NFL.passes_longer_20yards,passes_longer_20yards))
    
     #dados.add((stat_year,NFL.passes_longer_40yards,passes_longer_40yards))
     #dados.add((stat_year,NFL.sacks,sacks))
     #dados.add((stat_year,NFL.sacked_yards_lost,sacked_yards_lost))
     #dados.add((stat_year,NFL.passer_rating,passer_rating))

# %%
for row in dados_passing:
    
     stat = URIRef(pff+str(statid))
     statid= statid+1
    
     player = URIRef(NFL+id)
     name = URIRef(NFL+quote(row['Name']))
     team = URIRef(NFL+quote(row['Team']))
     games_played = Literal(row['Games Played'])
     passes_attempted = Literal(row['Passes Attempted'])
     passes_completed = Literal(row['Passes Completed'])
     completion_percentage = Literal(row['Completion Percentage'])
     pass_att_per_game = Literal(row['Pass Attempts Per Game'])
     passing_yards = Literal(row['Passing Yards'])
    
     passing_yards_att = Literal(row['Passing Yards Per Attempt'])
     passing_yards_game = Literal(row['Passing Yards Per Game'])
     td_passes = Literal(row['TD Passes'])
     percentage_tds_per_attemp = Literal(row['Percentage of TDs per Attempts'])
    
     interceptions = Literal(row['Ints'])
     interceptions_rate = Literal(row['Ints'])
     longest_pass = Literal(row['Longest Pass'])
     passes_longer_20yards = Literal(row['Passes Longer than 20 Yards'])
    
     passes_longer_40yards = Literal(row['Passes Longer than 40 Yards'])
     sacks = Literal(row['Sacks'])
     sacked_yards_lost = Literal(row['Sacked Yards Lost'])
     passer_rating = Literal(row['Passer Rating'])
    
     dados.add((stat, RDF.type, pff.stat))
     dados.add((stat, NFL.name, name))
     dados.add((stat, NFL.player, player))
     dados.add((stat,pff.passing_yards,passing_yards))
    
     dados.add((stat,NFL.team,team))
     dados.add((stat,pff.games_played,games_played))
     dados.add((stat,pff.passes_attempted,passes_attempted))
     dados.add((stat,pff.passes_completed,passes_completed))
     dados.add((stat,pff.completion_percentage,completion_percentage))
     dados.add((stat,pff.pass_att_per_game,pass_att_per_game))
     dados.add((stat,pff.passing_yards,passing_yards))
    
     dados.add((stat,pff.passing_yards_att,passing_yards_att))
     dados.add((stat,pff.passing_yards_game,passing_yards_game))
     dados.add((stat,pff.td_passes,td_passes))
     dados.add((stat,pff.percentage_tds_per_attemp,percentage_tds_per_attemp))
    
     dados.add((stat,pff.interceptions,interceptions))
     dados.add((stat,pff.interceptions_rate,interceptions_rate))
     dados.add((stat,pff.longest_pass,longest_pass))
     dados.add((stat,pff.passes_longer_20yards,passes_longer_20yards))
    
     dados.add((stat,pff.passes_longer_40yards,passes_longer_40yards))
     dados.add((stat,pff.sacks,sacks))
     dados.add((stat,pff.sacked_yards_lost,sacked_yards_lost))
     dados.add((stat,pff.passer_rating,passer_rating))

# %%
dados.bind("NFL",NFL)
dados.bind("Pro football Focus", pff)
dados.bind("Schema", Schema)

# %%
dados_final = dados.serialize(format="turtle")
#dados_final = dados.serialize(format="turtle").decode("utf-8")

print(dados_final.decode("utf-8"))
# Out:
# @prefix NFL: <http://www.nfl.com/> .
# @prefix Schema: <http://schema.org/> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# NFL:1 a Schema:SportsTeam ;
#     rdfs:label "Arizona Cardinals"@en ;
#     Schema:name "Arizona Cardinals" ;
#     Schema:sport "American Football" .
#
# NFL:10 a Schema:SportsTeam ;
#     rdfs:label "Denver Broncos"@en ;
#     Schema:atlete NFL:2559295 ;
#     Schema:name "Denver Broncos" ;
#     Schema:sport "American Football" .
#
# NFL:11 a Schema:SportsTeam ;
#     rdfs:label "Detroit Lions"@en ;
#     Schema:name "Detroit Lions" ;
#     Schema:sport "American Football" .
#
# NFL:12 a Schema:SportsTeam ;
#     rdfs:label "Green Bay Packers"@en ;
#     Schema:atlete NFL:2552263 ;
#     Schema:name "Green Bay Packers" ;
#     Schema:sport "American Football" .
#
# NFL:13 a Schema:SportsTeam ;
#     rdfs:label "Houston Texans"@en ;
#     Schema:atlete NFL:2543640 ;
#     Schema:name "Houston Texans" ;
#     Schema:sport "American Football" .
#
# NFL:14 a Schema:SportsTeam ;
#     rdfs:label "Indianapolis Colts"@en ;
#     Schema:name "Indianapolis Colts" ;
#     Schema:sport "American Football" .
#
# NFL:15 a Schema:SportsTeam ;
#     rdfs:label "Jacksonville Jaguars"@en ;
#     Schema:atlete NFL:2532873,
#         NFL:2558860 ;
#     Schema:name "Jacksonville Jaguars" ;
#     Schema:sport "American Football" .
#
# NFL:16 a Schema:SportsTeam ;
#     rdfs:label "Kansas City Chiefs"@en ;
#     Schema:atlete NFL:2543862,
#         NFL:2553790 ;
#     Schema:name "Kansas City Chiefs" ;
#     Schema:sport "American Football" .
#
# NFL:17 a Schema:SportsTeam ;
#     rdfs:label "Miami Dolphins"@en ;
#     Schema:atlete NFL:2508043,
#         NFL:2555201,
#         NFL:2555230,
#         NFL:2558070 ;
#     Schema:name "Miami Dolphins" ;
#     Schema:sport "American Football" .
#
# NFL:18 a Schema:SportsTeam ;
#     rdfs:label "Minnesota Vikings"@en ;
#     Schema:atlete NFL:2558915 ;
#     Schema:name "Minnesota Vikings" ;
#     Schema:sport "American Football" .
#
# NFL:19 a Schema:SportsTeam ;
#     rdfs:label "New England Patriots"@en ;
#     Schema:abstract "The New England Patriots are a professional American football team based in the Greater Boston region. The Patriots compete in the National Football League (NFL) as a member of the American Football Conference (AFC) East division. The team plays its home games at Gillette Stadium in the town of Foxborough, Massachusetts, which is located 21 miles (34 km) southwest of downtown Boston and 20 miles (32 km) northeast of downtown Providence, Rhode Island. The Patriots are also headquartered at Gillette Stadium. An original member of the American Football League (AFL), the Patriots joined the NFL in the 1970 merger of the two leagues. The team changed its name from the original Boston Patriots after relocating to Foxborough in 1971. The Patriots played their home games at Foxboro Stadium from 1971 to 2001, then moved to Gillette Stadium at the start of the 2002 season. The Patriots' rivalry with the New York Jets is considered one of the most bitter rivalries in the NFL. The Patriots have appeared in the Super Bowl eight times in franchise history, six of them since the arrival of head coach Bill Belichick and quarterback Tom Brady in 2000. The Patriots have since become one of the most successful teams in NFL history, winning twelve AFC East titles in 14 seasons since 2001, without a losing season in that period. The Patriots have since set numerous notable records, including most wins in a ten-year period (126, in 2003–2012), an undefeated 16-game regular season in 2007, and the longest winning streak consisting of regular season and playoff games in NFL history (a 21-game streak from October 2003 to October 2004). The Patriots own the record for most Super Bowls reached by a head coach-quarterback tandem (six), as well as being the first tandem to win the Super Bowl 14 years after the first." ;
#     Schema:atlete NFL:238498,
#         NFL:2508101,
#         NFL:2532907,
#         NFL:2533062,
#         NFL:2535132,
#         NFL:2543498,
#         NFL:2552255,
#         NFL:2552271,
#         NFL:2552392,
#         NFL:2552657,
#         NFL:2553632,
#         NFL:2553665,
#         NFL:2555145,
#         NFL:2555517,
#         NFL:2556525,
#         NFL:2558040,
#         NFL:2558908,
#         NFL:2559002,
#         NFL:2559036,
#         NFL:2559038,
#         NFL:2559374,
#         NFL:497240,
#         NFL:71251 ;
#     Schema:coach <http://dbpedia.org/resource/Bill_Belichick> ;
#     Schema:formationDate "1959-11-16"^^xsd:date ;
#     Schema:name "New England Patriots" ;
#     Schema:noSbChamps "4"^^xsd:int ;
#     Schema:owner <http://dbpedia.org/resource/Robert_Kraft> ;
#     Schema:sport "American Football" .
#
# NFL:2 a Schema:SportsTeam ;
#     rdfs:label "Atlanta Falcons"@en ;
#     Schema:abstract "The Atlanta Falcons are a professional American football team based in Atlanta, Georgia. The Falcons compete in the National Football League (NFL) as a member club of the league's National Football Conference (NFC) South division. The Falcons joined the NFL in 1965 as an expansion team, after the NFL offered then-owner Rankin Smith a franchise to keep him from joining the rival American Football League (AFL). The AFL instead granted a franchise to Miami (the Miami Dolphins). The Falcons are tied with the Dolphins (who also began play in 1966) for being the oldest NFL franchise in the Deep South, and are the oldest NFC team in that region. In their 51 years of existence, the Falcons have compiled a record of 316–414–6, winning division championships in 1980, 1998, 2004, 2010, and 2012. Their only Super Bowl appearance was during the 1998 season in Super Bowl XXXIII. The Falcons play their home games at the Georgia Dome in downtown Atlanta. Construction began on Mercedes-Benz Stadium in May 2014, with play projected to begin there during the 2017 season. Their headquarters and practice facilities are located at a 50-acre site in Flowery Branch, Georgia." ;
#     Schema:coach <http://dbpedia.org/resource/Dan_Quinn_(American_football)> ;
#     Schema:formationDate "1965-06-30"^^xsd:date ;
#     Schema:name "Atlanta Falcons" ;
#     Schema:noSbChamps "41"^^xsd:int ;
#     Schema:owner <http://dbpedia.org/resource/Arthur_Blank> ;
#     Schema:sport "American Football" .
#
# NFL:20 a Schema:SportsTeam ;
#     rdfs:label "New Orleans Saints"@en ;
#     Schema:abstract "The New Orleans Saints are a professional American football team based in New Orleans, Louisiana. The Saints currently compete in the National Football League (NFL) as a member of the league's National Football Conference (NFC) South division. The team was founded by John W. Mecom Jr. and David Dixon and the city of New Orleans. The Saints began play in Tulane Stadium in 1967. The name \"Saints\" is an allusion to November 1 being All Saints Day in the Catholic faith, New Orleans' large Catholic population, and the spiritual \"When the Saints Go Marching In\", which is strongly associated with New Orleans and often sung by fans at games. The team's primary colors are old gold and black; their logo is a simplified fleur-de-lis. They played their home games in Tulane Stadium through the 1974 NFL season. The following year, they moved to the new Louisiana Superdome (now the Mercedes-Benz Superdome, since Mercedes-Benz has purchased the stadium's naming rights). For most of their first 20 years, the Saints were barely competitive, only getting to .500 twice. In 1987, they finished 12–3—their first-ever winning season—and qualified for the NFL playoffs for the first time in franchise history, but lost to the Minnesota Vikings 44–10. The next season of 1988 ended with a 10–6 record. In the year 2000, the Saints defeated the St. Louis Rams 31–28 to notch their first-ever playoff win. In 2005, Hurricane Katrina devastated New Orleans and much of the Gulf Coast region. The Superdome was used as an emergency temporary shelter for displaced residents. The stadium suffered damage from the hurricane (notably from flooding and part of the roof being torn off as well as internal damage), and from lack of available facilities. The Saints were forced to play their first scheduled home game against the New York Giants at Giants Stadium in East Rutherford, New Jersey (the Giants' home stadium); other home games were rescheduled at the Alamodome in San Antonio, Texas or Tiger Stadium in Baton Rouge, Louisiana. During the season, it was rumored that Saints owner Tom Benson might deem the Superdome unusable and seek to legally void his contract and relocate the team to San Antonio, where he has business interests. Ultimately, however, the Superdome was repaired and renovated in time for the 2006 season at an estimated cost of US$185 million. The New Orleans Saints' first post-Katrina home game was an emotionally charged Monday Night Football game versus their division rival, the Atlanta Falcons. The Saints, under rookie head coach Sean Payton and new quarterback Drew Brees, defeated the Falcons 23–3, and went on to notch the second playoff win in franchise history. The 2009 season was a historic one for the Saints. Winning a franchise-record 13 games, they qualified for Super Bowl XLIV and defeated the AFC champion Indianapolis Colts 31–17. To date, it is the only Super Bowl championship that they have won, and as it is the only Super Bowl the Saints have appeared in, they join the New York Jets and Tampa Bay Buccaneers as the only three NFL teams to win their lone Super Bowl appearance. Over the course of 49 seasons, the Saints have compiled an overall record of 331–418–5, with a regular-season record of 324–409–5 and a playoff record of 7–9." ;
#     Schema:atlete NFL:2532859 ;
#     Schema:coach <http://dbpedia.org/resource/Sean_Payton> ;
#     Schema:formationDate "1966-11-01"^^xsd:date ;
#     Schema:name "New Orleans Saints" ;
#     Schema:noSbChamps "1"^^xsd:int ;
#     Schema:owner <http://dbpedia.org/resource/Tom_Benson> ;
#     Schema:sport "American Football" .
#
# NFL:21 a Schema:SportsTeam ;
#     rdfs:label "New York Giants"@en ;
#     Schema:atlete NFL:2495164,
#         NFL:2539307,
#         NFL:2543689 ;
#     Schema:name "New York Giants" ;
#     Schema:sport "American Football" .
#
# NFL:22 a Schema:SportsTeam ;
#     rdfs:label "New York Jets"@en ;
#     Schema:atlete NFL:2557885 ;
#     Schema:name "New York Jets" ;
#     Schema:sport "American Football" .
#
# NFL:23 a Schema:SportsTeam ;
#     rdfs:label "Oakland Raiders"@en ;
#     Schema:atlete NFL:2550164,
#         NFL:496949 ;
#     Schema:name "Oakland Raiders" ;
#     Schema:sport "American Football" .
#
# NFL:24 a Schema:SportsTeam ;
#     rdfs:label "Philadelphia Eagles"@en ;
#     Schema:name "Philadelphia Eagles" ;
#     Schema:sport "American Football" .
#
# NFL:2495275 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/28/1989"^^xsd:date ;
#     Schema:familyName "Dell" ;
#     Schema:givenName " Mark" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "195"^^xsd:int ;
#     NFL:college "Michigan State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "2011"^^xsd:int,
#         "2012"^^xsd:int .
#
# NFL:2495605 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "2/6/1984"^^xsd:date ;
#     Schema:birthPlace "San Jose " ;
#     Schema:familyName "Frampton" ;
#     Schema:givenName " Eric" ;
#     Schema:height "71"^^xsd:int ;
#     Schema:weight "202"^^xsd:int ;
#     NFL:college "Washington State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:yearPlayed "2007"^^xsd:int,
#         "2008"^^xsd:int,
#         "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int,
#         "2012"^^xsd:int,
#         "2013"^^xsd:int .
#
# NFL:2495791 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1201-01-01"^^xsd:date ;
#     Schema:familyName "Zabransky" ;
#     Schema:givenName " Jared" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "219"^^xsd:int ;
#     NFL:college "Boise State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "2007"^^xsd:int .
#
# NFL:2499376 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1201-01-01"^^xsd:date ;
#     Schema:birthPlace "El Dorado " ;
#     Schema:familyName "Alderson" ;
#     Schema:givenName " Winston" ;
#     Schema:height "76"^^xsd:int ;
#     Schema:weight "344"^^xsd:int ;
#     NFL:college "Arkansas" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1997"^^xsd:int .
#
# NFL:25 a Schema:SportsTeam ;
#     rdfs:label "Pittsburgh Steelers"@en ;
#     Schema:abstract "The Pittsburgh Steelers are a professional American football team based in Pittsburgh, Pennsylvania. The Steelers compete in the National Football League (NFL), as a member club of the league's American Football Conference (AFC) North division. Founded in 1933, the Steelers are the oldest franchise in the AFC. In contrast with their status as perennial also-rans in the pre-merger NFL, where they were the oldest team to never win a league championship, the Steelers of the post-merger (modern) era are one of the most successful NFL franchises. Pittsburgh has won more Super Bowl titles (6), and hosted more (11) conference championship games than any other NFL team. The Steelers share the record for most AFC championships with the New England Patriots and the Denver Broncos (8), and the record for most conference championship games played in with the San Francisco 49ers (15). The Steelers share the record for most Super Bowl appearances with the Patriots, Broncos, and Dallas Cowboys (8). The Steelers lost their most recent championship appearance, Super Bowl XLV, on February 6, 2011. The Steelers were founded as the Pittsburgh Pirates on July 8, 1933, by Art Rooney, taking its original name from the baseball team of the same name, as was common practice for NFL teams at the time. To distinguish them from the baseball team, local media took to calling the football team the Rooneymen, an unofficial nickname which persisted for decades after the team adopted its current nickname. The ownership of the Steelers has remained within the Rooney family since its founding. The current owner is Art's son, Dan Rooney, who has given much control of the franchise to his son Art Rooney II. Long one of the NFL's flagship teams, the Steelers enjoy a large, widespread fanbase nicknamed Steeler Nation. The Steelers currently play their home games at Heinz Field on Pittsburgh's North Side in the North Shore neighborhood, which also hosts the University of Pittsburgh Panthers. Built in 2001, the stadium replaced Three Rivers Stadium which hosted the Steelers for 31 seasons. Prior to Three Rivers, the Steelers had played their games in Pitt Stadium and Forbes Field." ;
#     Schema:atlete NFL:2552444 ;
#     Schema:coach <http://dbpedia.org/resource/Mike_Tomlin> ;
#     Schema:formationDate "1933-05-19"^^xsd:date ;
#     Schema:name "Pittsburgh Steelers" ;
#     Schema:noSbChamps "6"^^xsd:int ;
#     Schema:owner <http://dbpedia.org/resource/Rooney_family> ;
#     Schema:sport "American Football" .
#
# NFL:2500536 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1001-01-01"^^xsd:date ;
#     Schema:birthPlace "Hamden " ;
#     Schema:familyName "Ellis" ;
#     Schema:givenName " Ed" ;
#     Schema:height "77"^^xsd:int ;
#     Schema:weight "325"^^xsd:int ;
#     NFL:college "Buffalo" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:yearPlayed "1997"^^xsd:int,
#         "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int .
#
# NFL:2502600 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "6/29/1977"^^xsd:date ;
#     Schema:birthPlace "Waxahachie " ;
#     Schema:familyName "Reagor" ;
#     Schema:givenName " Montae" ;
#     Schema:height "75"^^xsd:int ;
#     Schema:weight "285"^^xsd:int ;
#     NFL:college "Texas Tech" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "10"^^xsd:int ;
#     NFL:yearPlayed "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2502679 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1/7/1962"^^xsd:date ;
#     Schema:birthPlace "Fort Ord " ;
#     Schema:familyName "Rivera" ;
#     Schema:givenName " Ron" ;
#     Schema:height "75"^^xsd:int ;
#     Schema:weight "235"^^xsd:int ;
#     NFL:college "California" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:yearPlayed "1984"^^xsd:int,
#         "1985"^^xsd:int,
#         "1986"^^xsd:int,
#         "1987"^^xsd:int,
#         "1988"^^xsd:int,
#         "1989"^^xsd:int,
#         "1990"^^xsd:int,
#         "1991"^^xsd:int,
#         "1992"^^xsd:int .
#
# NFL:2503464 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "6/14/1963"^^xsd:date ;
#     Schema:birthPlace "New Orleans " ;
#     Schema:familyName "Verdin" ;
#     Schema:givenName " Clarence" ;
#     Schema:height "68"^^xsd:int ;
#     Schema:weight "160"^^xsd:int ;
#     NFL:college "Louisiana-Lafayette" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:yearPlayed "1986"^^xsd:int,
#         "1987"^^xsd:int,
#         "1988"^^xsd:int,
#         "1989"^^xsd:int,
#         "1990"^^xsd:int,
#         "1991"^^xsd:int,
#         "1992"^^xsd:int,
#         "1993"^^xsd:int,
#         "1994"^^xsd:int .
#
# NFL:2503572 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "4/12/1974"^^xsd:date ;
#     Schema:birthPlace "Jacksonville " ;
#     Schema:familyName "Weary" ;
#     Schema:givenName " Fred" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "181"^^xsd:int ;
#     NFL:college "Florida" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "6"^^xsd:int ;
#     NFL:yearPlayed "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int .
#
# NFL:2504264 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/8/1977"^^xsd:date ;
#     Schema:birthPlace "Houston " ;
#     Schema:familyName "Webster" ;
#     Schema:givenName " Jason" ;
#     Schema:height "69"^^xsd:int ;
#     Schema:weight "187"^^xsd:int ;
#     NFL:college "Texas A&M" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:yearPlayed "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2504395 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/17/1978"^^xsd:date ;
#     Schema:birthPlace "Fort Wayne " ;
#     Schema:familyName "Baker" ;
#     Schema:givenName " Jason" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "205"^^xsd:int ;
#     NFL:college "Iowa" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "11"^^xsd:int ;
#     NFL:yearPlayed "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int,
#         "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int .
#
# NFL:2504656 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/6/1978"^^xsd:date ;
#     Schema:birthPlace "San Luis Obispo Co. " ;
#     Schema:familyName "Tafoya" ;
#     Schema:givenName " Joe" ;
#     Schema:height "76"^^xsd:int ;
#     Schema:weight "258"^^xsd:int ;
#     NFL:college "Arizona" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:yearPlayed "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2506142 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "3/3/1983"^^xsd:date ;
#     Schema:familyName "Wallace" ;
#     Schema:givenName " Kyle" ;
#     Schema:height "78"^^xsd:int ;
#     Schema:weight "295"^^xsd:int ;
#     NFL:college "Georgia Tech" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "2005"^^xsd:int .
#
# NFL:2506362 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "6/9/1983"^^xsd:date ;
#     Schema:birthPlace "Bradenton " ;
#     Schema:familyName "Washington" ;
#     Schema:givenName " Fabian" ;
#     Schema:height "71"^^xsd:int ;
#     Schema:weight "175"^^xsd:int ;
#     NFL:college "Nebraska" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:yearPlayed "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int,
#         "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int .
#
# NFL:2507719 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/4/1986"^^xsd:date ;
#     Schema:birthPlace "Pensacola " ;
#     Schema:familyName "Randolph" ;
#     Schema:givenName " Dane" ;
#     Schema:height "77"^^xsd:int ;
#     Schema:weight "310"^^xsd:int ;
#     NFL:college "Maryland" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "0"^^xsd:int ;
#     NFL:yearPlayed "2009"^^xsd:int .
#
# NFL:2507748 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1101-01-01"^^xsd:date ;
#     Schema:familyName "Goldberg" ;
#     Schema:givenName " Cameron" ;
#     Schema:height "78"^^xsd:int ;
#     Schema:weight "265"^^xsd:int ;
#     NFL:college "Duke" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "2009"^^xsd:int .
#
# NFL:2508869 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "7/30/1937"^^xsd:date ;
#     Schema:birthPlace "Coffeyville " ;
#     Schema:familyName "Baker" ;
#     Schema:givenName " Dave" ;
#     Schema:height "72"^^xsd:int ;
#     Schema:weight "192"^^xsd:int ;
#     NFL:college "Oklahoma" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "1959"^^xsd:int,
#         "1960"^^xsd:int,
#         "1961"^^xsd:int .
#
# NFL:2509130 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1/21/1939"^^xsd:date ;
#     Schema:birthPlace "Laurel " ;
#     Schema:familyName "Bass" ;
#     Schema:givenName " Norm" ;
#     Schema:height "75"^^xsd:int ;
#     Schema:weight "210"^^xsd:int ;
#     NFL:college "U. of Pacific" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1964"^^xsd:int .
#
# NFL:2509286 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "2/9/1896"^^xsd:date ;
#     Schema:birthPlace "Cleveland " ;
#     Schema:familyName "Beckwith" ;
#     Schema:givenName " Norm" ;
#     Schema:height ""^^xsd:int ;
#     Schema:weight "150"^^xsd:int ;
#     NFL:college "No College" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1920"^^xsd:int .
#
# NFL:2509361 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "6/14/1957"^^xsd:date ;
#     Schema:birthPlace "Jamestown " ;
#     Schema:familyName "Bell" ;
#     Schema:givenName " Mark" ;
#     Schema:height "69"^^xsd:int ;
#     Schema:weight "175"^^xsd:int ;
#     NFL:college "Colorado State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:2512416 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "3/3/1943"^^xsd:date ;
#     Schema:birthPlace "Brooklyn " ;
#     Schema:familyName "D'Amato" ;
#     Schema:givenName " Mike" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "205"^^xsd:int ;
#     NFL:college "Hofstra" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1968"^^xsd:int .
#
# NFL:2512457 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/14/1954"^^xsd:date ;
#     Schema:birthPlace "Miami " ;
#     Schema:familyName "Darby" ;
#     Schema:givenName " Al" ;
#     Schema:height "77"^^xsd:int ;
#     Schema:weight "221"^^xsd:int ;
#     NFL:college "Florida" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int .
#
# NFL:2512597 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1/21/1953"^^xsd:date ;
#     Schema:birthPlace "Tecumseh " ;
#     Schema:familyName "Davis" ;
#     Schema:givenName " Tony" ;
#     Schema:height "71"^^xsd:int ;
#     Schema:weight "212"^^xsd:int ;
#     NFL:college "Nebraska" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "6"^^xsd:int ;
#     NFL:yearPlayed "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:2512778 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1201-01-01"^^xsd:date ;
#     Schema:birthPlace "Indianola " ;
#     Schema:familyName "Demory" ;
#     Schema:givenName " Bill" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "195"^^xsd:int ;
#     NFL:college "Arizona" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1973"^^xsd:int,
#         "1974"^^xsd:int .
#
# NFL:2512828 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1/15/1967"^^xsd:date ;
#     Schema:birthPlace "Scranton " ;
#     Schema:familyName "DeRiggi" ;
#     Schema:givenName " Fred" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "268"^^xsd:int ;
#     NFL:college "Syracuse" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1990"^^xsd:int .
#
# NFL:2513563 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "4/23/1959"^^xsd:date ;
#     Schema:birthPlace "New York " ;
#     Schema:familyName "Elliott" ;
#     Schema:givenName " Tony" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "282"^^xsd:int ;
#     NFL:college "North Texas" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:yearPlayed "1982"^^xsd:int,
#         "1983"^^xsd:int,
#         "1984"^^xsd:int,
#         "1985"^^xsd:int,
#         "1986"^^xsd:int,
#         "1987"^^xsd:int,
#         "1988"^^xsd:int .
#
# NFL:2513736 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/23/1921"^^xsd:date ;
#     Schema:birthPlace "Grand Rapids " ;
#     Schema:familyName "Evans" ;
#     Schema:givenName " Fred" ;
#     Schema:height "71"^^xsd:int ;
#     Schema:weight "185"^^xsd:int ;
#     NFL:college "Notre Dame" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "1946"^^xsd:int,
#         "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2513861 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/16/1920"^^xsd:date ;
#     Schema:birthPlace "Casper " ;
#     Schema:familyName "Farris" ;
#     Schema:givenName " Tom" ;
#     Schema:height "73"^^xsd:int ;
#     Schema:weight "185"^^xsd:int ;
#     NFL:college "Wisconsin" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "1946"^^xsd:int,
#         "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2514196 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/30/1958"^^xsd:date ;
#     Schema:birthPlace "Cincinnati " ;
#     Schema:familyName "Foley" ;
#     Schema:givenName " Tim" ;
#     Schema:height "78"^^xsd:int ;
#     Schema:weight "275"^^xsd:int ;
#     NFL:college "Notre Dame" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1981"^^xsd:int .
#
# NFL:2514295 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/11/1960"^^xsd:date ;
#     Schema:birthPlace "Temple " ;
#     Schema:familyName "Fowler" ;
#     Schema:givenName " Bobby" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "230"^^xsd:int ;
#     NFL:college "Louisiana Tech" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1985"^^xsd:int .
#
# NFL:2514537 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "6/21/1929"^^xsd:date ;
#     Schema:birthPlace "Akron " ;
#     Schema:familyName "Gain" ;
#     Schema:givenName " Bob" ;
#     Schema:height "75"^^xsd:int ;
#     Schema:weight "256"^^xsd:int ;
#     NFL:college "Kentucky" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "12"^^xsd:int ;
#     NFL:yearPlayed "1952"^^xsd:int,
#         "1953"^^xsd:int,
#         "1954"^^xsd:int,
#         "1955"^^xsd:int,
#         "1956"^^xsd:int,
#         "1957"^^xsd:int,
#         "1958"^^xsd:int,
#         "1959"^^xsd:int,
#         "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int .
#
# NFL:2514740 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/12/1924"^^xsd:date ;
#     Schema:birthPlace "Long Island " ;
#     Schema:familyName "Gehrke" ;
#     Schema:givenName " Bruce" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "190"^^xsd:int ;
#     NFL:college "Columbia" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1948"^^xsd:int .
#
# NFL:2515030 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "2/23/1919"^^xsd:date ;
#     Schema:birthPlace "Alverton " ;
#     Schema:familyName "Gonda" ;
#     Schema:givenName " George" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "175"^^xsd:int ;
#     NFL:college "Duquesne" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1942"^^xsd:int .
#
# NFL:2515842 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1001-01-01"^^xsd:date ;
#     Schema:birthPlace "Selma " ;
#     Schema:familyName "Harkey" ;
#     Schema:givenName " Lance" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "180"^^xsd:int ;
#     NFL:college "Illinois" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1987"^^xsd:int .
#
# NFL:2518101 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/29/1983"^^xsd:date ;
#     Schema:familyName "Kaleita" ;
#     Schema:givenName " Tom" ;
#     Schema:height "78"^^xsd:int ;
#     Schema:weight "318"^^xsd:int ;
#     NFL:college "Eastern Michigan" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "0"^^xsd:int ;
#     NFL:yearPlayed "2006"^^xsd:int .
#
# NFL:2518471 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/16/1950"^^xsd:date ;
#     Schema:birthPlace "Houston " ;
#     Schema:familyName "Kindle" ;
#     Schema:givenName " Greg" ;
#     Schema:height "76"^^xsd:int ;
#     Schema:weight "265"^^xsd:int ;
#     NFL:college "Tennessee State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:yearPlayed "1974"^^xsd:int,
#         "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int .
#
# NFL:2518652 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "3/19/1919"^^xsd:date ;
#     Schema:birthPlace "Chicago " ;
#     Schema:familyName "Knolla" ;
#     Schema:givenName " Johnny" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "180"^^xsd:int ;
#     NFL:college "Creighton" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1942"^^xsd:int,
#         "1943"^^xsd:int,
#         "1944"^^xsd:int,
#         "1945"^^xsd:int .
#
# NFL:2519112 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1001-01-01"^^xsd:date ;
#     Schema:birthPlace "Greenfield " ;
#     Schema:familyName "Larson" ;
#     Schema:givenName " Bill" ;
#     Schema:height "76"^^xsd:int ;
#     Schema:weight "225"^^xsd:int ;
#     NFL:college "Colorado State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:yearPlayed "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int .
#
# NFL:2519453 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1/23/1936"^^xsd:date ;
#     Schema:birthPlace "Los Angeles " ;
#     Schema:familyName "Lewis" ;
#     Schema:givenName " Joe" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "256"^^xsd:int ;
#     NFL:college "Compton CC CA" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "5"^^xsd:int ;
#     NFL:yearPlayed "1958"^^xsd:int,
#         "1959"^^xsd:int,
#         "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int .
#
# NFL:2520035 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "6/18/1910"^^xsd:date ;
#     Schema:birthPlace "Hillsboro " ;
#     Schema:familyName "Malone" ;
#     Schema:givenName " Chuck" ;
#     Schema:height "76"^^xsd:int ;
#     Schema:weight "206"^^xsd:int ;
#     NFL:college "Texas A&M" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:yearPlayed "1934"^^xsd:int,
#         "1935"^^xsd:int,
#         "1936"^^xsd:int,
#         "1937"^^xsd:int,
#         "1938"^^xsd:int,
#         "1939"^^xsd:int,
#         "1940"^^xsd:int,
#         "1941"^^xsd:int,
#         "1942"^^xsd:int .
#
# NFL:2520333 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1201-01-01"^^xsd:date ;
#     Schema:birthPlace "Rocky Mount " ;
#     Schema:familyName "Mathis" ;
#     Schema:givenName " Bill" ;
#     Schema:height "73"^^xsd:int ;
#     Schema:weight "220"^^xsd:int ;
#     NFL:college "Clemson" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "10"^^xsd:int ;
#     NFL:yearPlayed "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int,
#         "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int .
#
# NFL:2522114 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1101-01-01"^^xsd:date ;
#     Schema:birthPlace "St. Helena " ;
#     Schema:familyName "Nichelini" ;
#     Schema:givenName " Al" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "207"^^xsd:int ;
#     NFL:college "St. Mary's (CA)" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1935"^^xsd:int,
#         "1936"^^xsd:int .
#
# NFL:2522592 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1201-01-01"^^xsd:date ;
#     Schema:birthPlace "St. Louis " ;
#     Schema:familyName "Otto" ;
#     Schema:givenName " Gus" ;
#     Schema:height "73"^^xsd:int ;
#     Schema:weight "220"^^xsd:int ;
#     NFL:college "Missouri" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:yearPlayed "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int,
#         "1970"^^xsd:int,
#         "1971"^^xsd:int,
#         "1972"^^xsd:int .
#
# NFL:2523136 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/11/1892"^^xsd:date ;
#     Schema:birthPlace "Sumner " ;
#     Schema:familyName "Petty" ;
#     Schema:givenName " Ross" ;
#     Schema:height "73"^^xsd:int ;
#     Schema:weight "180"^^xsd:int ;
#     NFL:college "Illinois" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1920"^^xsd:int .
#
# NFL:2523147 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "7/31/1947"^^xsd:date ;
#     Schema:birthPlace "Canton " ;
#     Schema:familyName "Pharr" ;
#     Schema:givenName " Tommy" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "187"^^xsd:int ;
#     NFL:college "Mississippi State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1970"^^xsd:int .
#
# NFL:2523695 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "2/10/1961"^^xsd:date ;
#     Schema:birthPlace "Alton " ;
#     Schema:familyName "Raglin" ;
#     Schema:givenName " Floyd" ;
#     Schema:height "69"^^xsd:int ;
#     Schema:weight "180"^^xsd:int ;
#     NFL:college "Southern University" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1987"^^xsd:int .
#
# NFL:2523700 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1201-01-01"^^xsd:date ;
#     Schema:birthPlace "Dayton " ;
#     Schema:familyName "Raiff" ;
#     Schema:givenName " Jim" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "235"^^xsd:int ;
#     NFL:college "Dayton" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1954"^^xsd:int .
#
# NFL:2523928 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/14/1927"^^xsd:date ;
#     Schema:birthPlace "Bridgeton " ;
#     Schema:familyName "Reid" ;
#     Schema:givenName " Breezy" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "187"^^xsd:int ;
#     NFL:college "Georgia" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:yearPlayed "1950"^^xsd:int,
#         "1951"^^xsd:int,
#         "1952"^^xsd:int,
#         "1953"^^xsd:int,
#         "1954"^^xsd:int,
#         "1955"^^xsd:int,
#         "1956"^^xsd:int .
#
# NFL:2524829 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "7/7/1956"^^xsd:date ;
#     Schema:birthPlace "Baytown " ;
#     Schema:familyName "Sampson" ;
#     Schema:givenName " Howard" ;
#     Schema:height "70"^^xsd:int ;
#     Schema:weight "185"^^xsd:int ;
#     NFL:college "Arkansas" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1978"^^xsd:int,
#         "1979"^^xsd:int .
#
# NFL:2524989 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "8/12/1930"^^xsd:date ;
#     Schema:birthPlace "Baltimore " ;
#     Schema:familyName "Scarbath" ;
#     Schema:givenName " Jack" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "206"^^xsd:int ;
#     NFL:college "Maryland" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "1953"^^xsd:int,
#         "1954"^^xsd:int,
#         "1955"^^xsd:int,
#         "1956"^^xsd:int .
#
# NFL:2525128 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1001-01-01"^^xsd:date ;
#     Schema:birthPlace "Birmingham " ;
#     Schema:familyName "Schuler" ;
#     Schema:givenName " Bill" ;
#     Schema:height "72"^^xsd:int ;
#     Schema:weight "215"^^xsd:int ;
#     NFL:college "Yale" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:yearPlayed "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2525255 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/16/1960"^^xsd:date ;
#     Schema:birthPlace "Ann Arbor " ;
#     Schema:familyName "Sealby" ;
#     Schema:givenName " Randy" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "230"^^xsd:int ;
#     NFL:college "Missouri" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1987"^^xsd:int .
#
# NFL:2525335 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/22/1918"^^xsd:date ;
#     Schema:birthPlace "Chicopee Falls " ;
#     Schema:familyName "Sergienko" ;
#     Schema:givenName " George" ;
#     Schema:height "73"^^xsd:int ;
#     Schema:weight "248"^^xsd:int ;
#     NFL:college "American International" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:yearPlayed "1943"^^xsd:int,
#         "1944"^^xsd:int,
#         "1945"^^xsd:int,
#         "1946"^^xsd:int .
#
# NFL:2527011 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "3/8/1945"^^xsd:date ;
#     Schema:birthPlace "Orlando " ;
#     Schema:familyName "Tanner" ;
#     Schema:givenName " John" ;
#     Schema:height "76"^^xsd:int ;
#     Schema:weight "231"^^xsd:int ;
#     NFL:college "Tennessee Tech" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "1971"^^xsd:int,
#         "1972"^^xsd:int,
#         "1973"^^xsd:int,
#         "1974"^^xsd:int .
#
# NFL:2527085 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1001-01-01"^^xsd:date ;
#     Schema:birthPlace "Richmond " ;
#     Schema:familyName "Taylor" ;
#     Schema:givenName " Greg" ;
#     Schema:height "68"^^xsd:int ;
#     Schema:weight "175"^^xsd:int ;
#     NFL:college "Virginia" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1982"^^xsd:int .
#
# NFL:2527193 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1/11/1949"^^xsd:date ;
#     Schema:birthPlace "Brownsville " ;
#     Schema:familyName "Thaxton" ;
#     Schema:givenName " Jim" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "240"^^xsd:int ;
#     NFL:college "Tennessee State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "5"^^xsd:int ;
#     NFL:yearPlayed "1973"^^xsd:int,
#         "1974"^^xsd:int,
#         "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int .
#
# NFL:2527241 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/1/1942"^^xsd:date ;
#     Schema:birthPlace "Barberton " ;
#     Schema:familyName "Thomas" ;
#     Schema:givenName " Gene" ;
#     Schema:height "73"^^xsd:int ;
#     Schema:weight "210"^^xsd:int ;
#     NFL:college "Florida A&M" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int .
#
# NFL:2527303 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate ""^^xsd:date ;
#     Schema:familyName "Thompson" ;
#     Schema:givenName " Pinky" ;
#     Schema:height ""^^xsd:int ;
#     Schema:weight ""^^xsd:int ;
#     NFL:college "No College" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "1927"^^xsd:int .
#
# NFL:2530581 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "9/12/1988"^^xsd:date ;
#     Schema:birthPlace "Carbondale " ;
#     Schema:familyName "Hall" ;
#     Schema:givenName " Bryan" ;
#     Schema:height "72"^^xsd:int ;
#     Schema:weight "280"^^xsd:int ;
#     NFL:college "Arkansas State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "2011"^^xsd:int,
#         "2012"^^xsd:int,
#         "2013"^^xsd:int .
#
# NFL:2530729 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1001-01-01"^^xsd:date ;
#     Schema:birthPlace "Evanston " ;
#     Schema:familyName "Riley" ;
#     Schema:givenName " Chris" ;
#     Schema:height "77"^^xsd:int ;
#     Schema:weight "305"^^xsd:int ;
#     NFL:college "Illinois State" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "2011"^^xsd:int,
#         "2012"^^xsd:int .
#
# NFL:2530849 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "2/18/1987"^^xsd:date ;
#     Schema:birthPlace "Frankfurt Germany" ;
#     Schema:familyName "Lewis" ;
#     Schema:givenName " Andrew" ;
#     Schema:height "74"^^xsd:int ;
#     Schema:weight "303"^^xsd:int ;
#     NFL:college "Syracuse" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "2011"^^xsd:int .
#
# NFL:2532782 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "1101-01-01"^^xsd:date ;
#     Schema:birthPlace "Little Rock " ;
#     Schema:familyName "Adams" ;
#     Schema:givenName " Joe" ;
#     Schema:height "71"^^xsd:int ;
#     Schema:weight "185"^^xsd:int ;
#     NFL:college "Arkansas" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:yearPlayed "2012"^^xsd:int,
#         "2013"^^xsd:int,
#         "2014"^^xsd:int .
#
# NFL:2541732 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "2/15/1990"^^xsd:date ;
#     Schema:birthPlace "Reno " ;
#     Schema:familyName "Nady" ;
#     Schema:givenName " Jeff" ;
#     Schema:height "79"^^xsd:int ;
#     Schema:weight "305"^^xsd:int ;
#     NFL:college "Nevada" ;
#     NFL:currentStatus "Retired" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:yearPlayed "2013"^^xsd:int .
#
# NFL:2541971 a Schema:Person,
#         Schema:athlete ;
#     rdfs:label "Washington Redskins"@en ;
#     Schema:Gender Schema:Male ;
#     Schema:birthDate "5/3/1990"^^xsd:date ;
#     Schema:familyName "Castillo" ;
#     Schema:givenName " Greg" ;
#     Schema:height "71"^^xsd:int ;
# ...
#     NFL:sacks "41" ;
#     NFL:td_passes "18" ;
#     NFL:team <http://www.nfl.com/Pittsburgh%20Steelers> ;
#     NFL:year "2003" .
#
# <http://www.nfl.com/tommymaddox/2501842/2004> a NFL:playerseason ;
#     rdfs:label "2004"@en ;
#     NFL:completion_percentage "50" ;
#     NFL:games_played "4" ;
#     NFL:interceptions "2" ;
#     NFL:interceptions_rate "2" ;
#     NFL:longest_pass "39" ;
#     NFL:name <http://www.nfl.com/Maddox%2C%20Tommy> ;
#     NFL:pass_att_per_game "15" ;
#     NFL:passer_rating "58.3" ;
#     NFL:passes_attempted "60" ;
#     NFL:passes_completed "30" ;
#     NFL:passes_longer_20yards "4" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "329" ;
#     NFL:passing_yards_att "5.5" ;
#     NFL:passing_yards_game "82.2" ;
#     NFL:percentage_tds_per_attemp "1.7" ;
#     NFL:sacked_yards_lost "37" ;
#     NFL:sacks "6" ;
#     NFL:td_passes "1" ;
#     NFL:team <http://www.nfl.com/Pittsburgh%20Steelers> ;
#     NFL:year "2004" .
#
# <http://www.nfl.com/tommymaddox/2501842/2005> a NFL:playerseason ;
#     rdfs:label "2005"@en ;
#     NFL:completion_percentage "47.9" ;
#     NFL:games_played "4" ;
#     NFL:interceptions "4" ;
#     NFL:interceptions_rate "4" ;
#     NFL:longest_pass "32" ;
#     NFL:name <http://www.nfl.com/Maddox%2C%20Tommy> ;
#     NFL:pass_att_per_game "17.8" ;
#     NFL:passer_rating "51.7" ;
#     NFL:passes_attempted "71" ;
#     NFL:passes_completed "34" ;
#     NFL:passes_longer_20yards "6" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "406" ;
#     NFL:passing_yards_att "5.7" ;
#     NFL:passing_yards_game "101.5" ;
#     NFL:percentage_tds_per_attemp "2.8" ;
#     NFL:sacked_yards_lost "43" ;
#     NFL:sacks "8" ;
#     NFL:td_passes "2" ;
#     NFL:team <http://www.nfl.com/Pittsburgh%20Steelers> ;
#     NFL:year "2005" .
#
# <http://www.nfl.com/tommymason/2520296/1961> a NFL:playerseason ;
#     rdfs:label "1961"@en ;
#     NFL:completion_percentage "0" ;
#     NFL:games_played "13" ;
#     NFL:interceptions "0" ;
#     NFL:interceptions_rate "0" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0.1" ;
#     NFL:passer_rating "39.6" ;
#     NFL:passes_attempted "1" ;
#     NFL:passes_completed "0" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "0" ;
#     NFL:passing_yards_att "0" ;
#     NFL:passing_yards_game "0" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Minnesota%20Vikings> ;
#     NFL:year "1961" .
#
# <http://www.nfl.com/tommymason/2520296/1962> a NFL:playerseason ;
#     rdfs:label "1962"@en ;
#     NFL:completion_percentage "0" ;
#     NFL:games_played "14" ;
#     NFL:interceptions "1" ;
#     NFL:interceptions_rate "1" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0.1" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "1" ;
#     NFL:passes_completed "0" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "0" ;
#     NFL:passing_yards_att "0" ;
#     NFL:passing_yards_game "0" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Minnesota%20Vikings> ;
#     NFL:year "1962" .
#
# <http://www.nfl.com/tommymason/2520296/1963> a NFL:playerseason ;
#     rdfs:label "1963"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "13" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Minnesota%20Vikings> ;
#     NFL:year "1963" .
#
# <http://www.nfl.com/tommymason/2520296/1964> a NFL:playerseason ;
#     rdfs:label "1964"@en ;
#     NFL:completion_percentage "100" ;
#     NFL:games_played "13" ;
#     NFL:interceptions "0" ;
#     NFL:interceptions_rate "0" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0.1" ;
#     NFL:passer_rating "158.3" ;
#     NFL:passes_attempted "1" ;
#     NFL:passes_completed "1" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "30" ;
#     NFL:passing_yards_att "30" ;
#     NFL:passing_yards_game "2.3" ;
#     NFL:percentage_tds_per_attemp "100" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "1" ;
#     NFL:team <http://www.nfl.com/Minnesota%20Vikings> ;
#     NFL:year "1964" .
#
# <http://www.nfl.com/tommymason/2520296/1965> a NFL:playerseason ;
#     rdfs:label "1965"@en ;
#     NFL:completion_percentage "0" ;
#     NFL:games_played "10" ;
#     NFL:interceptions "1" ;
#     NFL:interceptions_rate "1" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0.1" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "1" ;
#     NFL:passes_completed "0" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "0" ;
#     NFL:passing_yards_att "0" ;
#     NFL:passing_yards_game "0" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Minnesota%20Vikings> ;
#     NFL:year "1965" .
#
# <http://www.nfl.com/tommymason/2520296/1966> a NFL:playerseason ;
#     rdfs:label "1966"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "7" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Minnesota%20Vikings> ;
#     NFL:year "1966" .
#
# <http://www.nfl.com/tommymason/2520296/1967> a NFL:playerseason ;
#     rdfs:label "1967"@en ;
#     NFL:completion_percentage "66.7" ;
#     NFL:games_played "13" ;
#     NFL:interceptions "0" ;
#     NFL:interceptions_rate "0" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0.2" ;
#     NFL:passer_rating "149.3" ;
#     NFL:passes_attempted "3" ;
#     NFL:passes_completed "2" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "65" ;
#     NFL:passing_yards_att "21.7" ;
#     NFL:passing_yards_game "5" ;
#     NFL:percentage_tds_per_attemp "33.3" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "1" ;
#     NFL:team <http://www.nfl.com/Los%20Angeles%20Rams> ;
#     NFL:year "1967" .
#
# <http://www.nfl.com/tommymason/2520296/1968> a NFL:playerseason ;
#     rdfs:label "1968"@en ;
#     NFL:completion_percentage "0" ;
#     NFL:games_played "12" ;
#     NFL:interceptions "0" ;
#     NFL:interceptions_rate "0" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0.2" ;
#     NFL:passer_rating "39.6" ;
#     NFL:passes_attempted "2" ;
#     NFL:passes_completed "0" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "0" ;
#     NFL:passing_yards_att "0" ;
#     NFL:passing_yards_game "0" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Los%20Angeles%20Rams> ;
#     NFL:year "1968" .
#
# <http://www.nfl.com/tommymason/2520296/1969> a NFL:playerseason ;
#     rdfs:label "1969"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "13" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Los%20Angeles%20Rams> ;
#     NFL:year "1969" .
#
# <http://www.nfl.com/tommymason/2520296/1970> a NFL:playerseason ;
#     rdfs:label "1970"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "6" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Los%20Angeles%20Rams> ;
#     NFL:year "1970" .
#
# <http://www.nfl.com/tommymason/2520296/1971> a NFL:playerseason ;
#     rdfs:label "1971"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "10" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Mason%2C%20Tommy> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Washington%20Redskins> ;
#     NFL:year "1971" .
#
# <http://www.nfl.com/tomsavage/2543640/2014> a NFL:playerseason ;
#     rdfs:label "2014"@en ;
#     NFL:completion_percentage "52.6" ;
#     NFL:games_played "2" ;
#     NFL:interceptions "1" ;
#     NFL:interceptions_rate "1" ;
#     NFL:longest_pass "35" ;
#     NFL:name <http://www.nfl.com/Savage%2C%20Tom> ;
#     NFL:pass_att_per_game "9.5" ;
#     NFL:passer_rating "51.9" ;
#     NFL:passes_attempted "19" ;
#     NFL:passes_completed "10" ;
#     NFL:passes_longer_20yards "2" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "127" ;
#     NFL:passing_yards_att "6.7" ;
#     NFL:passing_yards_game "63.5" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "5" ;
#     NFL:sacks "1" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Houston%20Texans> ;
#     NFL:year "2014" .
#
# <http://www.nfl.com/tomsavage/2543640/2016> a NFL:playerseason ;
#     rdfs:label "2016"@en ;
#     NFL:completion_percentage "63" ;
#     NFL:games_played "3" ;
#     NFL:interceptions "0" ;
#     NFL:interceptions_rate "0" ;
#     NFL:longest_pass "32" ;
#     NFL:name <http://www.nfl.com/Savage%2C%20Tom> ;
#     NFL:pass_att_per_game "24.3" ;
#     NFL:passer_rating "80.9" ;
#     NFL:passes_attempted "73" ;
#     NFL:passes_completed "46" ;
#     NFL:passes_longer_20yards "5" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "461" ;
#     NFL:passing_yards_att "6.3" ;
#     NFL:passing_yards_game "153.7" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "36" ;
#     NFL:sacks "5" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Houston%20Texans> ;
#     NFL:year "2016" .
#
# <http://www.nfl.com/tonykaska/2518165/1935> a NFL:playerseason ;
#     rdfs:label "1935"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "2" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Kaska%2C%20Tony> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Detroit%20Lions> ;
#     NFL:year "1935" .
#
# <http://www.nfl.com/tonykaska/2518165/1936> a NFL:playerseason ;
#     rdfs:label "1936"@en ;
#     NFL:completion_percentage "0" ;
#     NFL:games_played "12" ;
#     NFL:interceptions "1" ;
#     NFL:interceptions_rate "1" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Kaska%2C%20Tony> ;
#     NFL:pass_att_per_game "0.1" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "1" ;
#     NFL:passes_completed "0" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "0" ;
#     NFL:passing_yards_att "0" ;
#     NFL:passing_yards_game "0" ;
#     NFL:percentage_tds_per_attemp "0" ;
#     NFL:sacked_yards_lost "0" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "0" ;
#     NFL:team <http://www.nfl.com/Brooklyn%20Dodgers> ;
#     NFL:year "1936" .
#
# <http://www.nfl.com/tonykaska/2518165/1937> a NFL:playerseason ;
#     rdfs:label "1937"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "10" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Kaska%2C%20Tony> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Brooklyn%20Dodgers> ;
#     NFL:year "1937" .
#
# <http://www.nfl.com/tonykaska/2518165/1938> a NFL:playerseason ;
#     rdfs:label "1938"@en ;
#     NFL:completion_percentage "--" ;
#     NFL:games_played "11" ;
#     NFL:interceptions "--" ;
#     NFL:interceptions_rate "--" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Kaska%2C%20Tony> ;
#     NFL:pass_att_per_game "0" ;
#     NFL:passer_rating "0" ;
#     NFL:passes_attempted "--" ;
#     NFL:passes_completed "--" ;
#     NFL:passes_longer_20yards "--" ;
#     NFL:passes_longer_40yards "--" ;
#     NFL:passing_yards "--" ;
#     NFL:passing_yards_att "--" ;
#     NFL:passing_yards_game "--" ;
#     NFL:percentage_tds_per_attemp "--" ;
#     NFL:sacked_yards_lost "--" ;
#     NFL:sacks "--" ;
#     NFL:td_passes "--" ;
#     NFL:team <http://www.nfl.com/Brooklyn%20Dodgers> ;
#     NFL:year "1938" .
#
# <http://www.nfl.com/virgileikenberg/2513524/1948> a NFL:playerseason ;
#     rdfs:label "1948"@en ;
#     NFL:completion_percentage "31.6" ;
#     NFL:games_played "9" ;
#     NFL:interceptions "2" ;
#     NFL:interceptions_rate "2" ;
#     NFL:longest_pass "--" ;
#     NFL:name <http://www.nfl.com/Eikenberg%2C%20Virgil> ;
#     NFL:pass_att_per_game "2.1" ;
#     NFL:passer_rating "53.8" ;
#     NFL:passes_attempted "19" ;
#     NFL:passes_completed "6" ;
#     NFL:passes_longer_20yards "0" ;
#     NFL:passes_longer_40yards "0" ;
#     NFL:passing_yards "116" ;
#     NFL:passing_yards_att "6.1" ;
#     NFL:passing_yards_game "12.9" ;
#     NFL:percentage_tds_per_attemp "15.8" ;
#     NFL:sacked_yards_lost "68" ;
#     NFL:sacks "0" ;
#     NFL:td_passes "3" ;
#     NFL:team <http://www.nfl.com/Chicago%20Cardinals> ;
#     NFL:year "1948" .

# %%
fil=open("nfl_data_test.ttl", "wb") # Causa erro, espera por um ficheiro tipo bytes e recebe str. Retirei o b
#fil=open("nfl_data_test.ttl", "w")
fil.write(dados_final)
fil.close()

# %%
# Running in Fuseki

# Don't forget to change to java -Xmx1200M -jar fuseki-server.jar --conf config_fuseki.ttl %*

# In your config_fuseki.ttl file, change the following parameters:

#:baseModel a ja:MemoryModel ;
#    ja:content [ja:externalContent <file:D:/Documents/GitHub/FWS_Grupo_2/nfl_data_test.ttl> ] ;
    
#Optional

#Change the inference model to just RDFS in this section of the configuration file, which should read as

# The inference model

#:model_inf a ja:InfModel ;
#     ja:baseModel :baseModel ;
#     ja:reasoner [
#         ja:reasonerURL <http://jena.hpl.hp.com/2003/RDFSExptRuleReasoner>
#     ] .

# %%
sparql = SPARQLWrapper("http://localhost:3030/dataset/query")

query="""
prefix ex: <http://example.com/> 
prefix foaf: <http://xmlns.com/foaf/0.1/> 
prefix imdb: <http://imdb.com/> 
prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> 
prefix riaa: <http://riaa.org/> 

SELECT ?s ?p ?o 
WHERE {
  # ?s ?p ?o .
} 
"""
sparql.setQuery(query)
sparql.setReturnFormat(TSV)
results = sparql.query().convert().decode("utf-8")
print(results)
# Out:
# ?s	?p	?o
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#rest>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#rest>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#List>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#rest>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#List>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#rest>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#rest>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#List>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#List>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#label>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#Literal>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Class>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Class>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Resource>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#subject>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#subject>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#subject>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#subject>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Datatype>
# <http://www.w3.org/2000/01/rdf-schema#comment>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#Literal>
# <http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#object>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#object>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#object>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#object>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#nil>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#List>
# <http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Literal>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Literal>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#first>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#first>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#List>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#first>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#first>
# <http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.nfl.com/2527011>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2527011>	<http://schema.org/birthPlace>	"Orlando "
# <http://www.nfl.com/2527011>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2527011>	<http://www.nfl.com/yearPlayed>	"1972"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2527011>	<http://schema.org/height>	"76"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2527011>	<http://schema.org/givenName>	" John"
# <http://www.nfl.com/2527011>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2527011>	<http://www.nfl.com/yearPlayed>	"1973"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2527011>	<http://schema.org/birthDate>	"3/8/1945"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2527011>	<http://schema.org/familyName>	"Tanner"
# <http://www.nfl.com/2527011>	<http://www.nfl.com/currentStatus>	"Retired"
# <http://www.nfl.com/2527011>	<http://www.nfl.com/yearPlayed>	"1974"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2527011>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2527011>	<http://www.nfl.com/experience>	"3"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2527011>	<http://www.nfl.com/college>	"Tennessee Tech"
# <http://www.nfl.com/2527011>	<http://schema.org/weight>	"231"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2527011>	<http://www.nfl.com/yearPlayed>	"1971"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/td_passes>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/name>	<http://www.nfl.com/Barnes%2C%20Billy>
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/games_played>	"10"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passes_attempted>	"4"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passer_rating>	"114.6"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/sacked_yards_lost>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/year>	"1962"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/interceptions>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passing_yards_game>	"4.8"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.w3.org/2000/01/rdf-schema#label>	"1962"@en
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/completion_percentage>	"75"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/pass_att_per_game>	"0.4"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/team>	<http://www.nfl.com/Washington%20Redskins>
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/interceptions_rate>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passing_yards_att>	"12"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/percentage_tds_per_attemp>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/sacks>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passes_completed>	"3"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passes_longer_40yards>	"0"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passing_yards>	"48"
# <http://www.nfl.com/billybarnes/2509009/1962>	<http://www.nfl.com/passes_longer_20yards>	"0"
# <http://www.nfl.com/2532905>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2532905>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://schema.org/familyName>	"McCants"
# <http://www.nfl.com/2532905>	<http://www.nfl.com/college>	"Alabama-Birmingham"
# <http://www.nfl.com/2532905>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2532905>	<http://schema.org/weight>	"310"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://www.nfl.com/experience>	"5"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://schema.org/birthDate>	"8/18/1989"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2532905>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2532905>	<http://www.nfl.com/highSchool>	"Lillie B. Williamson "
# <http://www.nfl.com/2532905>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://www.nfl.com/position>	"T"
# <http://www.nfl.com/2532905>	<http://www.nfl.com/yearPlayed>	"1981"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://schema.org/givenName>	" Matt"
# <http://www.nfl.com/2532905>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2532905>	<http://schema.org/height>	"78"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/2532905>	<http://schema.org/birthPlace>	"Mobile "
# <http://www.nfl.com/2532905>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2532905>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://schema.org/birthPlace>	"Johns Creek "
# <http://www.nfl.com/2553632>	<http://schema.org/height>	"75"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/highSchool>	"Wesleyan School "
# <http://www.nfl.com/2553632>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2553632>	<http://schema.org/birthDate>	"7/10/1992"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2553632>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2553632>	<http://www.nfl.com/experience>	"3"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/yearPlayed>	"1981"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://schema.org/givenName>	" David"
# <http://www.nfl.com/2553632>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/2553632>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/playerNumber>	"60"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://schema.org/weight>	""^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://schema.org/familyName>	"Andrews"
# <http://www.nfl.com/2553632>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2553632>	<http://www.nfl.com/college>	"Georgia"
# <http://www.nfl.com/2553632>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1988>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1989>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1990>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1991>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1992>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1993>
# <http://www.nfl.com/tommieagee/2499365>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/tommieagee/2499365/1994>
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passing_yards_att>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/team>	<http://www.nfl.com/Buffalo%20Bills>
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passer_rating>	"0"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passes_longer_40yards>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/interceptions>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/name>	<http://www.nfl.com/Maguire%2C%20Paul>
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passes_completed>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/sacks>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/interceptions_rate>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passes_attempted>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/games_played>	"14"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/completion_percentage>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passing_yards_game>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/percentage_tds_per_attemp>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passes_longer_20yards>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/sacked_yards_lost>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/pass_att_per_game>	"0"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/year>	"1967"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/td_passes>	"--"
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.w3.org/2000/01/rdf-schema#label>	"1967"@en
# <http://www.nfl.com/paulmaguire/2519977/1967>	<http://www.nfl.com/passing_yards>	"--"
# <http://www.nfl.com/23>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/SportsTeam>
# <http://www.nfl.com/23>	<http://www.w3.org/2000/01/rdf-schema#label>	"Oakland Raiders"@en
# <http://www.nfl.com/23>	<http://schema.org/atlete>	<http://www.nfl.com/2550164>
# <http://www.nfl.com/23>	<http://schema.org/atlete>	<http://www.nfl.com/496949>
# <http://www.nfl.com/23>	<http://schema.org/name>	"Oakland Raiders"
# <http://www.nfl.com/23>	<http://schema.org/sport>	"American Football"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/team>	<http://www.nfl.com/Denver%20Broncos>
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passes_longer_40yards>	"0"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/pass_att_per_game>	"9.3"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/interceptions>	"9"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/sacked_yards_lost>	"60"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passes_completed>	"66"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/interceptions_rate>	"9"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passer_rating>	"56.4"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passing_yards_att>	"6.3"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passes_attempted>	"121"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/td_passes>	"5"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passing_yards_game>	"58.2"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passing_yards>	"757"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/year>	"1992"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/completion_percentage>	"54.5"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/games_played>	"13"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.w3.org/2000/01/rdf-schema#label>	"1992"@en
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/sacks>	"10"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/longest_pass>	"38"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/percentage_tds_per_attemp>	"4.1"
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/name>	<http://www.nfl.com/Maddox%2C%20Tommy>
# <http://www.nfl.com/tommymaddox/2501842/1992>	<http://www.nfl.com/passes_longer_20yards>	"12"
# <http://www.nfl.com/2507719>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2507719>	<http://schema.org/height>	"77"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2507719>	<http://schema.org/birthDate>	"9/4/1986"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2507719>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2507719>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2507719>	<http://schema.org/givenName>	" Dane"
# <http://www.nfl.com/2507719>	<http://schema.org/familyName>	"Randolph"
# <http://www.nfl.com/2507719>	<http://www.nfl.com/experience>	"0"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2507719>	<http://schema.org/birthPlace>	"Pensacola "
# <http://www.nfl.com/2507719>	<http://www.nfl.com/college>	"Maryland"
# <http://www.nfl.com/2507719>	<http://www.nfl.com/currentStatus>	"Retired"
# <http://www.nfl.com/2507719>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2507719>	<http://www.nfl.com/yearPlayed>	"2009"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2507719>	<http://schema.org/weight>	"310"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passes_completed>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/name>	<http://www.nfl.com/Nichelini%2C%20Al>
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passes_attempted>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/completion_percentage>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/year>	"1936"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/interceptions>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/sacked_yards_lost>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/sacks>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passes_longer_40yards>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/td_passes>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passing_yards>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/interceptions_rate>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passer_rating>	"0"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passing_yards_game>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/pass_att_per_game>	"0"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passing_yards_att>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.w3.org/2000/01/rdf-schema#label>	"1936"@en
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/games_played>	"12"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/team>	<http://www.nfl.com/Chicago%20Cardinals>
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/passes_longer_20yards>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/percentage_tds_per_attemp>	"--"
# <http://www.nfl.com/alnichelini/2522114/1936>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passing_yards_game>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/year>	"1948"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passes_attempted>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/name>	<http://www.nfl.com/Farris%2C%20Tom>
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passes_completed>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/percentage_tds_per_attemp>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.w3.org/2000/01/rdf-schema#label>	"1948"@en
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/games_played>	"0"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/pass_att_per_game>	"0"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passes_longer_40yards>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passes_longer_20yards>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passer_rating>	"0"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passing_yards>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/passing_yards_att>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/completion_percentage>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/sacked_yards_lost>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/td_passes>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/sacks>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/team>	<http://www.nfl.com/Chicago%20Rockets>
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/interceptions_rate>	"--"
# <http://www.nfl.com/tomfarris/2513861/1948>	<http://www.nfl.com/interceptions>	"--"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/sacks>	"0"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passing_yards_game>	"16.9"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/sacked_yards_lost>	"0"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/pass_att_per_game>	"4.6"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passes_longer_20yards>	"0"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/team>	<http://www.nfl.com/Washington%20Redskins>
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passes_attempted>	"46"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/year>	"1945"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/percentage_tds_per_attemp>	"2.2"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/name>	<http://www.nfl.com/Filchock%2C%20Frank>
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passes_completed>	"18"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passing_yards>	"169"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passing_yards_att>	"3.7"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/interceptions_rate>	"7"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.w3.org/2000/01/rdf-schema#label>	"1945"@en
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/games_played>	"10"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passer_rating>	"17.7"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/completion_percentage>	"39.1"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/interceptions>	"7"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/td_passes>	"1"
# <http://www.nfl.com/frankfilchock/2514016/1945>	<http://www.nfl.com/passes_longer_40yards>	"0"
# <http://www.nfl.com/2556677>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/2556677>	<http://www.nfl.com/experience>	"1"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2556677>	<http://schema.org/birthDate>	"1201-01-01"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/position>	"DE"
# <http://www.nfl.com/2556677>	<http://schema.org/givenName>	" Ian"
# <http://www.nfl.com/2556677>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2556677>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2556677>	<http://schema.org/weight>	"256"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://schema.org/height>	"74"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/college>	"Nevada"
# <http://www.nfl.com/2556677>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/yearPlayed>	"1981"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2556677>	<http://schema.org/familyName>	"Seau"
# <http://www.nfl.com/2530729>	<http://www.nfl.com/currentStatus>	"Retired"
# <http://www.nfl.com/2530729>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2530729>	<http://schema.org/birthDate>	"1001-01-01"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2530729>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2530729>	<http://www.nfl.com/experience>	"1"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2530729>	<http://schema.org/weight>	"305"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2530729>	<http://schema.org/height>	"77"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2530729>	<http://www.nfl.com/yearPlayed>	"2011"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2530729>	<http://www.nfl.com/yearPlayed>	"2012"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2530729>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2530729>	<http://www.nfl.com/college>	"Illinois State"
# <http://www.nfl.com/2530729>	<http://schema.org/familyName>	"Riley"
# <http://www.nfl.com/2530729>	<http://schema.org/birthPlace>	"Evanston "
# <http://www.nfl.com/2530729>	<http://schema.org/givenName>	" Chris"
# <http://www.nfl.com/2530729>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2522114>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2522114>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2522114>	<http://schema.org/height>	"74"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2522114>	<http://schema.org/givenName>	" Al"
# <http://www.nfl.com/2522114>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2522114>	<http://www.nfl.com/experience>	"2"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2522114>	<http://www.nfl.com/currentStatus>	"Retired"
# <http://www.nfl.com/2522114>	<http://schema.org/birthPlace>	"St. Helena "
# <http://www.nfl.com/2522114>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2522114>	<http://www.nfl.com/yearPlayed>	"1935"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2522114>	<http://www.nfl.com/yearPlayed>	"1936"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2522114>	<http://schema.org/familyName>	"Nichelini"
# <http://www.nfl.com/2522114>	<http://schema.org/weight>	"207"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2522114>	<http://schema.org/birthDate>	"1101-01-01"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2522114>	<http://www.nfl.com/college>	"St. Mary's (CA)"
# <http://www.nfl.com/jodiewhire/2528624>	<http://www.nfl.com/playerseason>	<http://www.nfl.com/jodiewhire/2528624/1933>
# <http://www.nfl.com/2550164>	<http://schema.org/birthDate>	"7/28/1990"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/experience>	"4"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/college>	"Ohio U."
# <http://www.nfl.com/2550164>	<http://www.nfl.com/yearPlayed>	"1975"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/position>	"SS"
# <http://www.nfl.com/2550164>	<http://schema.org/givenName>	" T.J."
# <http://www.nfl.com/2550164>	<http://schema.org/height>	"72"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2550164>	<http://schema.org/birthPlace>	"Rodeo "
# <http://www.nfl.com/2550164>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/2550164>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2550164>	<http://www.nfl.com/highSchool>	"De La Salle "
# <http://www.nfl.com/2550164>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/playerNumber>	"38"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://schema.org/familyName>	"Carrie"
# <http://www.nfl.com/2550164>	<http://schema.org/weight>	"205"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2550164>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/position>	"DE"
# <http://www.nfl.com/2558915>	<http://schema.org/givenName>	" Tashawn"
# <http://www.nfl.com/2558915>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/college>	"LSU"
# <http://www.nfl.com/2558915>	<http://schema.org/familyName>	"Bower"
# <http://www.nfl.com/2558915>	<http://www.nfl.com/experience>	"1"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://schema.org/height>	"77"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/yearPlayed>	"1981"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/2558915>	<http://schema.org/birthDate>	"2/18/1995"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2558915>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2558915>	<http://www.nfl.com/highSchool>	"Immaculata "
# <http://www.nfl.com/2558915>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2558915>	<http://schema.org/birthPlace>	"Livingston "
# <http://www.nfl.com/2558915>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://schema.org/weight>	"250"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2558915>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2558915>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passing_yards>	"2"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/games_played>	"8"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/name>	<http://www.nfl.com/Vaughan%2C%20Harp>
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passer_rating>	"0"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/interceptions_rate>	"3"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passing_yards_game>	"0.2"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/year>	"1933"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passing_yards_att>	"0.3"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/completion_percentage>	"25"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/pass_att_per_game>	"1"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passes_completed>	"2"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/team>	<http://www.nfl.com/Pittsburgh%20Pirates>
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/interceptions>	"3"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passes_longer_40yards>	"0"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/td_passes>	"0"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.w3.org/2000/01/rdf-schema#label>	"1933"@en
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passes_longer_20yards>	"0"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/sacks>	"0"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/percentage_tds_per_attemp>	"0"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/passes_attempted>	"8"
# <http://www.nfl.com/harpvaughan/2527911/1933>	<http://www.nfl.com/sacked_yards_lost>	"0"
# <http://www.nfl.com/3>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/SportsTeam>
# <http://www.nfl.com/3>	<http://www.w3.org/2000/01/rdf-schema#label>	"Baltimore Ravens"@en
# <http://www.nfl.com/3>	<http://schema.org/name>	"Baltimore Ravens"
# <http://www.nfl.com/3>	<http://schema.org/sport>	"American Football"
# <http://www.nfl.com/2502600>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/college>	"Texas Tech"
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2003"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2004"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2502600>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"1999"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://schema.org/familyName>	"Reagor"
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2001"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2000"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2002"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2007"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/currentStatus>	"Retired"
# <http://www.nfl.com/2502600>	<http://schema.org/height>	"75"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2008"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://schema.org/birthDate>	"6/29/1977"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2502600>	<http://schema.org/weight>	"285"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2005"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2502600>	<http://www.nfl.com/experience>	"10"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://schema.org/givenName>	" Montae"
# <http://www.nfl.com/2502600>	<http://www.nfl.com/yearPlayed>	"2006"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2502600>	<http://schema.org/birthPlace>	"Waxahachie "
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/sacked_yards_lost>	"232"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/interceptions>	"21"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/sacks>	"27"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passer_rating>	"65.4"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/interceptions_rate>	"21"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passes_completed>	"226"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passing_yards_att>	"6.7"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.w3.org/2000/01/rdf-schema#label>	"1971"@en
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/td_passes>	"11"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/games_played>	"13"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/percentage_tds_per_attemp>	"2.8"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passing_yards>	"2,567"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passes_longer_20yards>	"0"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passes_attempted>	"386"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/pass_att_per_game>	"29.7"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/name>	<http://www.nfl.com/Tarkenton%2C%20Fran>
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passes_longer_40yards>	"0"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/passing_yards_game>	"197.5"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/completion_percentage>	"58.5"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/year>	"1971"
# <http://www.nfl.com/frantarkenton/2527019/1971>	<http://www.nfl.com/team>	<http://www.nfl.com/New%20York%20Giants>
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/pass_att_per_game>	"0"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/team>	<http://www.nfl.com/Dallas%20Cowboys>
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passing_yards>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/percentage_tds_per_attemp>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passing_yards_game>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passes_longer_40yards>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/interceptions_rate>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passes_attempted>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/sacks>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/sacked_yards_lost>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/interceptions>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/name>	<http://www.nfl.com/Agee%2C%20Tommie>
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passes_longer_20yards>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/games_played>	"16"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.w3.org/2000/01/rdf-schema#label>	"1992"@en
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passing_yards_att>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/year>	"1992"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passer_rating>	"0"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/td_passes>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/completion_percentage>	"--"
# <http://www.nfl.com/tommieagee/2499365/1992>	<http://www.nfl.com/passes_completed>	"--"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/td_passes>	"1"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/year>	"2004"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passes_attempted>	"60"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/sacked_yards_lost>	"37"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/games_played>	"4"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/interceptions>	"2"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passer_rating>	"58.3"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passing_yards_att>	"5.5"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passes_longer_40yards>	"0"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/completion_percentage>	"50"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/pass_att_per_game>	"15"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passes_completed>	"30"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/sacks>	"6"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/name>	<http://www.nfl.com/Maddox%2C%20Tommy>
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passing_yards>	"329"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.w3.org/2000/01/rdf-schema#label>	"2004"@en
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/longest_pass>	"39"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.nfl.com/playerseason>
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/interceptions_rate>	"2"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passes_longer_20yards>	"4"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/percentage_tds_per_attemp>	"1.7"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/passing_yards_game>	"82.2"
# <http://www.nfl.com/tommymaddox/2501842/2004>	<http://www.nfl.com/team>	<http://www.nfl.com/Pittsburgh%20Steelers>
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/passing_yards_att>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/team>	<http://www.nfl.com/Minnesota%20Vikings>
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/sacked_yards_lost>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/passing_yards>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/passing_yards_game>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/games_played>	"13"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/passes_completed>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/percentage_tds_per_attemp>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/name>	<http://www.nfl.com/Mason%2C%20Tommy>
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/td_passes>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/longest_pass>	"--"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/completion_percentage>	"0"
# <http://www.nfl.com/tommymason/2520296/1961>	<http://www.nfl.com/interceptions>	"0"
# ...
# <http://www.nfl.com/496980>	<http://www.nfl.com/experience>	"8"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/496980>	<http://schema.org/weight>	"305"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/college>	"Utah"
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1966"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1981"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1964"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://schema.org/height>	"76"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://schema.org/givenName>	" Zane"
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1969"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/496980>	<http://schema.org/birthDate>	"1101-01-01"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/496980>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1961"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1968"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://schema.org/birthPlace>	"Casper "
# <http://www.nfl.com/496980>	<http://www.nfl.com/playerNumber>	"68"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1963"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://schema.org/familyName>	"Beadles"
# <http://www.nfl.com/496980>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1965"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/position>	"G"
# <http://www.nfl.com/496980>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1962"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1960"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/496980>	<http://www.nfl.com/highSchool>	"Hillcrest "
# <http://www.nfl.com/2495164>	<http://schema.org/birthPlace>	"Kirkwood "
# <http://www.nfl.com/2495164>	<http://www.nfl.com/yearPlayed>	"1980"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/Person>
# <http://www.nfl.com/2495164>	<http://schema.org/Gender>	<http://schema.org/Male>
# <http://www.nfl.com/2495164>	<http://www.nfl.com/yearPlayed>	"1981"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.nfl.com/yearPlayed>	"1976"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.nfl.com/position>	"OLB"
# <http://www.nfl.com/2495164>	<http://www.nfl.com/experience>	"7"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.w3.org/2000/01/rdf-schema#label>	"Washington Redskins"@en
# <http://www.nfl.com/2495164>	<http://schema.org/birthDate>	"9/1/1987"^^<http://www.w3.org/2001/XMLSchema#date>
# <http://www.nfl.com/2495164>	<http://www.nfl.com/yearPlayed>	"1978"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.nfl.com/playerNumber>	"44"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://schema.org/height>	"76"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.nfl.com/yearPlayed>	"1979"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://schema.org/weight>	"246"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.nfl.com/2495164>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://schema.org/athlete>
# <http://www.nfl.com/2495164>	<http://schema.org/familyName>	"Herzlich"
# <http://www.nfl.com/2495164>	<http://www.nfl.com/college>	"Boston College"
# <http://www.nfl.com/2495164>	<http://www.nfl.com/currentStatus>	"Active"
# <http://www.nfl.com/2495164>	<http://schema.org/givenName>	" Mark"
# <http://www.nfl.com/2495164>	<http://www.nfl.com/highSchool>	"Conestoga "
# <http://www.nfl.com/2495164>	<http://www.nfl.com/yearPlayed>	"1977"^^<http://www.w3.org/2001/XMLSchema#int>
# <http://www.w3.org/2000/01/rdf-schema#Resource>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Container>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Container>
# <http://www.w3.org/2000/01/rdf-schema#Datatype>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Datatype>
# <http://www.w3.org/2000/01/rdf-schema#Datatype>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Datatype>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Class>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#List>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#List>
# <http://www.w3.org/2000/01/rdf-schema#Literal>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Literal>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Container>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>
# <http://www.w3.org/2000/01/rdf-schema#Container>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Container>
# <http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty>
# <http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty>	<http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#isDefinedBy>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/2000/01/rdf-schema#isDefinedBy>
# <http://www.w3.org/2000/01/rdf-schema#isDefinedBy>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/2000/01/rdf-schema#seeAlso>
# <http://www.w3.org/2000/01/rdf-schema#seeAlso>	<http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/2000/01/rdf-schema#seeAlso>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Container>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#Datatype>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/2000/01/rdf-schema#isDefinedBy>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#seeAlso>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#comment>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.w3.org/2000/01/rdf-schema#label>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>
# <http://www.nfl.com/playerseason>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://schema.org/SportsTeam>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://schema.org/athlete>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://schema.org/Person>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#XMLLiteral>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Class>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#nil>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#first>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#object>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#subject>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#predicate>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#rest>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#isDefinedBy>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#seeAlso>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#subClassOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#domain>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#subPropertyOf>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#range>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#comment>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#label>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Property>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#List>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Resource>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Class>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Statement>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Literal>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Bag>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Container>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Seq>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#Datatype>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/1999/02/22-rdf-syntax-ns#Alt>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.w3.org/2000/01/rdf-schema#ContainerMembershipProperty>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://www.nfl.com/playerseason>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://schema.org/SportsTeam>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://schema.org/athlete>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>
# <http://schema.org/Person>	<http://www.w3.org/1999/02/22-rdf-syntax-ns#type>	<http://www.w3.org/2000/01/rdf-schema#Resource>

# %%
# qres = dados.query(
#     """SELECT ?id
#        WHERE {
#           ?p a Schema:SportsTeam .
#           ?p NFL:id ?id.
#           ?p Schema:name "Hoston Texans"
#        }LIMIT 50""")
# for row in qres:
#     print("%s " % row)

# %%
#     q = prepareQuery(
#      """SELECT ?id
#        WHERE {
#           ?p a Schema:SportsTeam .
#           ?p NFL:id ?id.
#           ?p Schema:name ?name
#        }LIMIT 50""")

#     for row in dados.query(q, initBindings={"name": "Houston Texans"}):
#      print(row)

# %%
nome_equipa = "New England Patriots"
sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.addDefaultGraph("http://dbpedia.org")
query =Template( """
    PREFIX dbpedia: <http://dbpedia.org/resource/> 
    Select ?team ?coach
     WHERE{ 
        # ?team rdfs:label "$nome_equipa"@en;
        dbo:coach ?coach.
    }
""")


sparql.setQuery(query.substitute(uri="New England Patriots"))
sparql.setReturnFormat(JSON)
results = sparql.query().convert()

for result in results["results"]["bindings"]:
    coach = str(result["coach"]["value"])
    print(coach)
