# %%
# Entrega II cadeira Web-semantica @ Fcul 2020-2021
# Realizado por João Pinto(55018) e Ricardo Meireles(xxxxx)

# %%
import csv
import rdflib
from rdflib import Graph, Literal, Namespace, URIRef, BNode
from rdflib.plugins.sparql import prepareQuery
from rdflib.namespace import DCTERMS, RDF, RDFS, XSD
from urllib.parse import quote

NFL = Namespace('http://www.nfl.com/')
pff = Namespace('http://www.pff.com/')

Schema = Namespace("http://schema.org/")
Schema.Person = rdflib.term.URIRef(u'http://schema.org/Person')
Schema.City = rdflib.term.URIRef(u'http://schema.org/City')
Schema.SportsTeam = rdflib.term.URIRef(u'http://schema.org/SportsTeam')
Schema.Athlete = rdflib.term.URIRef(u'http://schema.org/athlete')
Schema.CollegeOrUniversity = rdflib.term.URIRef(u'http://schema.org/CollegeOrUniversity')

statid=1

dados_equipas = csv.DictReader(open("nfl_teams.csv"))
dados_base = csv.DictReader(open("Basic_Stats_Sample.csv"))
dados_passing = csv.DictReader(open("Career_Stats_Passing_Sample.csv"))

dados = Graph()

# %%
for row in dados_equipas:
    idequipa =row['ID']
    nomeequipa = row ['Name']
    equipa=URIRef(NFL+idequipa)
    
    dados.add((equipa, RDF.type, Schema.SportsTeam))
    dados.add((equipa,Schema.name,Literal(nomeequipa)))
    dados.add((equipa,Schema.sport,Literal("American Football")))
    dados.add((equipa,NFL.id,Literal(idequipa)))

# %%
for row in dados_base:
    
    id =row['Player Id'] 
    
    
    current_team = row['Current Team']
    
    
    
    
    name = Literal(row['Name'])
    #position = URIRef(NFL+quote(row['Position']))
    player_number = Literal(row['Number'],datatype=XSD.int)
    #current_status = URIRef(NFL+quote(row['Current Status']))
    experience = Literal(row['Experience'])
    birth_place = URIRef(NFL+quote(row['Birth Place']))
    birth_day = Literal(row['Birthday'])
    college = URIRef(NFL+quote(row['College']))
    high_school = URIRef(NFL+quote(row['High School']))
    high_school_location = URIRef(NFL+quote(row['High School Location']))
    height = Literal(row['Height (inches)'],datatype=XSD.int)
    weight = Literal(row['Weight (lbs)'],datatype=XSD.int)
    year_played = Literal(row['Years Played'])
    

    
    string_player = str(id)
    
    player = URIRef(NFL+string_player.split('/')[1])
    dados.add((player, RDF.type, Schema.Athlete))
    #dados.add((player, RDFS.label, Literal(id, lang="en")))
    
    string_exp = row['Experience']
    if string_exp:
     temp = re.findall(r'\d+', string_exp) 
     res = list(map(int, temp)) 
     dados.add((player, NFL.experience, Literal(res[0],datatype=XSD.int)))
    
    
    dados.add((player,Schema.birthDate,birth_day))

#     dados.add((player, NFL.current_team, current_team))
#     dados.add((player, NFL.position, position))
#     dados.add((player, NFL.player_number, player_number))
#     dados.add((player, NFL.current_status, current_status))
    
#     dados.add((player, NFL.birth_place, birth_place))
#     dados.add((player, NFL.college, college))
#     dados.add((player, NFL.high_school, NFL.high_school))
#     dados.add((player, NFL.high_school_location, high_school_location)) 
    
#     dados.add((player, Schema.height, height))
#     dados.add((player, Schema.weight, weight))
    
    
    # Tratamento do campo name, separar por nome e nome de familia e addicionar o triplo com o schema
    string_name = str(name)
    dados.add((player, Schema.givenName, Literal(string_name.split(',')[1] )))  
    dados.add((player, Schema.familyName, Literal(string_name.split(',')[0] )))  
    
    # Tratamento do years played, separar por temporada e addicionar todas ao triplo
    string_years = str(year_played)
    if  string_years:  
     nums = [int(n) for n in string_years.split('-')] 
    x = range(nums[0], nums[1]+1)
    for n in x: 
     dados.add((player, NFL.year_played, Literal(n,datatype=XSD.int)))   
    
#     qres = dados.query(
#     """SELECT ?id
#        WHERE {
#           ?p a Schema:SportsTeam .
#           ?p NFL:id ?id.
#           ?p Schema:name ?name
#           FILTER regex(?name, "Houston Texans")
#        }LIMIT 50""")

for row in qres:
    idteste=URIRef(NFL+"%s" % row)
    print(idteste)

# %%
# for row in dados_passing:
    

    
#     stat = Literal(row['year'])
    
    
#         sid= URIRef(sls+s["sid"])
#     buyer= URIRef(aff+s["buyer"])
#     seller= URIRef(aff+s["seller"])
#     product= URIRef(sls+s["product"])
#     quant=Literal(s["quantity"],datatype=XSD.int)
#     cost=Literal(s["cost"],datatype=XSD.real)

#     G.add((sid, RDF.type, sls.Sale))
#     G.add((sid, sls.Buyer, buyer))
#     G.add((sid, sls.Seller, seller))
#     G.add((sid, sls.Product, product))
#     G.add((sid, sls.Quantity, quant))
#     G.add((sid, sls.Cost, cost))
    
#     dados.add(stat, RDF.type, pff.stat)
    
#     id =row['Player Id'] 
    
#     player = URIRef(NFL+id)

# #     year = Literal(row['Year'])
    
# #     playerseason= URIRef(NFL+id+"/"+quote(row['Year']))
    
#     name = URIRef(NFL+quote(row['Name']))
#     team = URIRef(NFL+quote(row['Team']))
#     games_played = Literal(row['Games Played'])
#     passes_attempted = Literal(row['Passes Attempted'])
#     passes_completed = Literal(row['Passes Completed'])
#     completion_percentage = Literal(row['Completion Percentage'])
#     pass_att_per_game = Literal(row['Pass Attempts Per Game'])
#     passing_yards = Literal(row['Passing Yards'])
    
#     passing_yards_att = Literal(row['Passing Yards Per Attempt'])
#     passing_yards_game = Literal(row['Passing Yards Per Game'])
#     td_passes = Literal(row['TD Passes'])
#     percentage_tds_per_attemp = Literal(row['Percentage of TDs per Attempts'])
    
#     interceptions = Literal(row['Ints'])
#     interceptions_rate = Literal(row['Ints'])
#     longest_pass = Literal(row['Longest Pass'])
#     passes_longer_20yards = Literal(row['Passes Longer than 20 Yards'])
    
#     passes_longer_40yards = Literal(row['Passes Longer than 40 Yards'])
#     sacks = Literal(row['Sacks'])
#     sacked_yards_lost = Literal(row['Sacked Yards Lost'])
#     passer_rating = Literal(row['Passer Rating'])
  

#     dados.add((playerseason, RDF.type, NFL.playerseason))
#     dados.add((playerseason, RDFS.label, Literal(year, lang="en")))

#     dados.add((player, NFL.playerseason, playerseason))

#     dados.add((playerseason,NFL.team,team))
#     dados.add((playerseason,NFL.games_played,games_played))
#     dados.add((playerseason,NFL.passes_attempted,passes_attempted))
#     dados.add((playerseason,NFL.passes_completed,passes_completed))
#     dados.add((playerseason,NFL.completion_percentage,completion_percentage))
#     dados.add((playerseason,NFL.pass_att_per_game,pass_att_per_game))
#     dados.add((playerseason,NFL.passing_yards,passing_yards))
    
#     dados.add((playerseason,NFL.passing_yards_att,passing_yards_att))
#     dados.add((playerseason,NFL.passing_yards_game,passing_yards_game))
#     dados.add((playerseason,NFL.td_passes,td_passes))
#     dados.add((playerseason,NFL.percentage_tds_per_attemp,percentage_tds_per_attemp))
    
#     dados.add((playerseason,NFL.interceptions,interceptions))
#     dados.add((playerseason,NFL.interceptions_rate,interceptions_rate))
#     dados.add((playerseason,NFL.longest_pass,longest_pass))
#     dados.add((playerseason,NFL.passes_longer_20yards,passes_longer_20yards))
    
#     dados.add((playerseason,NFL.passes_longer_40yards,passes_longer_40yards))
#     dados.add((playerseason,NFL.sacks,sacks))
#     dados.add((playerseason,NFL.sacked_yards_lost,sacked_yards_lost))
#     dados.add((playerseason,NFL.passer_rating,passer_rating))
    
#     dados.add((playerseason, NFL.name, name ))  
#     dados.add((playerseason, NFL.year, year ))  


#     dados.add((player, NFL.player_stat, player_stat ))  
#     dados.add((player_stat, year, stat_year ))
    
#     dados.add((stat_year,NFL.team,team))
#     dados.add((stat_year,NFL.games_played,games_played))
#     dados.add((stat_year,NFL.passes_attempted,passes_attempted))
#     dados.add((stat_year,NFL.passes_completed,passes_completed))
#     dados.add((stat_year,NFL.completion_percentage,completion_percentage))
#     dados.add((stat_year,NFL.pass_att_per_game,pass_att_per_game))
#     dados.add((stat_year,NFL.passing_yards,passing_yards))
    
#     dados.add((stat_year,NFL.passing_yards_att,passing_yards_att))
#     dados.add((stat_year,NFL.passing_yards_game,passing_yards_game))
#     dados.add((stat_year,NFL.td_passes,td_passes))
#     dados.add((stat_year,NFL.percentage_tds_per_attemp,percentage_tds_per_attemp))
    
#     dados.add((stat_year,NFL.interceptions,interceptions))
#     dados.add((stat_year,NFL.interceptions_rate,interceptions_rate))
#     dados.add((stat_year,NFL.longest_pass,longest_pass))
#     dados.add((stat_year,NFL.passes_longer_20yards,passes_longer_20yards))
    
#     dados.add((stat_year,NFL.passes_longer_40yards,passes_longer_40yards))
#     dados.add((stat_year,NFL.sacks,sacks))
#     dados.add((stat_year,NFL.sacked_yards_lost,sacked_yards_lost))
#     dados.add((stat_year,NFL.passer_rating,passer_rating))

# %%
# for row in dados_passing:
    
#     stat = URIRef(pff+str(statid))
#     statid= statid+1
    
#     player = URIRef(NFL+id)
#     name = URIRef(NFL+quote(row['Name']))
#     team = URIRef(NFL+quote(row['Team']))
#     games_played = Literal(row['Games Played'])
#     passes_attempted = Literal(row['Passes Attempted'])
#     passes_completed = Literal(row['Passes Completed'])
#     completion_percentage = Literal(row['Completion Percentage'])
#     pass_att_per_game = Literal(row['Pass Attempts Per Game'])
#     passing_yards = Literal(row['Passing Yards'])
    
#     passing_yards_att = Literal(row['Passing Yards Per Attempt'])
#     passing_yards_game = Literal(row['Passing Yards Per Game'])
#     td_passes = Literal(row['TD Passes'])
#     percentage_tds_per_attemp = Literal(row['Percentage of TDs per Attempts'])
    
#     interceptions = Literal(row['Ints'])
#     interceptions_rate = Literal(row['Ints'])
#     longest_pass = Literal(row['Longest Pass'])
#     passes_longer_20yards = Literal(row['Passes Longer than 20 Yards'])
    
#     passes_longer_40yards = Literal(row['Passes Longer than 40 Yards'])
#     sacks = Literal(row['Sacks'])
#     sacked_yards_lost = Literal(row['Sacked Yards Lost'])
#     passer_rating = Literal(row['Passer Rating'])
    
#     dados.add((stat, RDF.type, pff.stat))
#     dados.add((stat, NFL.name, name))
#     dados.add((stat, NFL.player, player))
#     dados.add((stat,pff.passing_yards,passing_yards))
    
#     dados.add((stat,NFL.team,team))
#     dados.add((stat,pff.games_played,games_played))
#     dados.add((stat,pff.passes_attempted,passes_attempted))
#     dados.add((stat,pff.passes_completed,passes_completed))
#     dados.add((stat,pff.completion_percentage,completion_percentage))
#     dados.add((stat,pff.pass_att_per_game,pass_att_per_game))
#     dados.add((stat,pff.passing_yards,passing_yards))
    
#     dados.add((stat,pff.passing_yards_att,passing_yards_att))
#     dados.add((stat,pff.passing_yards_game,passing_yards_game))
#     dados.add((stat,pff.td_passes,td_passes))
#     dados.add((stat,pff.percentage_tds_per_attemp,percentage_tds_per_attemp))
    
#     dados.add((stat,pff.interceptions,interceptions))
#     dados.add((stat,pff.interceptions_rate,interceptions_rate))
#     dados.add((stat,pff.longest_pass,longest_pass))
#     dados.add((stat,pff.passes_longer_20yards,passes_longer_20yards))
    
#     dados.add((stat,pff.passes_longer_40yards,passes_longer_40yards))
#     dados.add((stat,pff.sacks,sacks))
#     dados.add((stat,pff.sacked_yards_lost,sacked_yards_lost))
#     dados.add((stat,pff.passer_rating,passer_rating))

# %%
dados.bind("NFL",NFL)
dados.bind("Pro football Focus", pff)
dados.bind("Schema", Schema)

# %%
print(dados.serialize(format="turtle").decode("utf-8"))
# Out:
# @prefix NFL: <http://www.nfl.com/> .
# @prefix Schema: <http://schema.org/> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# NFL:1 a Schema:SportsTeam ;
#     Schema:name "Arizona Cardinals" ;
#     Schema:sport "American Football" ;
#     NFL:id "1" .
#
# NFL:10 a Schema:SportsTeam ;
#     Schema:name "Denver Broncos" ;
#     Schema:sport "American Football" ;
#     NFL:id "10" .
#
# NFL:11 a Schema:SportsTeam ;
#     Schema:name "Detroit Lions" ;
#     Schema:sport "American Football" ;
#     NFL:id "11" .
#
# NFL:12 a Schema:SportsTeam ;
#     Schema:name "Green Bay Packers" ;
#     Schema:sport "American Football" ;
#     NFL:id "12" .
#
# NFL:13 a Schema:SportsTeam ;
#     Schema:name "Houston Texans" ;
#     Schema:sport "American Football" ;
#     NFL:id "13" .
#
# NFL:14 a Schema:SportsTeam ;
#     Schema:name "Indianapolis Colts" ;
#     Schema:sport "American Football" ;
#     NFL:id "14" .
#
# NFL:15 a Schema:SportsTeam ;
#     Schema:name "Jacksonville Jaguars" ;
#     Schema:sport "American Football" ;
#     NFL:id "15" .
#
# NFL:16 a Schema:SportsTeam ;
#     Schema:name "Kansas City Chiefs" ;
#     Schema:sport "American Football" ;
#     NFL:id "16" .
#
# NFL:17 a Schema:SportsTeam ;
#     Schema:name "Miami Dolphins" ;
#     Schema:sport "American Football" ;
#     NFL:id "17" .
#
# NFL:18 a Schema:SportsTeam ;
#     Schema:name "Minnesota Vikings" ;
#     Schema:sport "American Football" ;
#     NFL:id "18" .
#
# NFL:19 a Schema:SportsTeam ;
#     Schema:name "New England Patriots" ;
#     Schema:sport "American Football" ;
#     NFL:id "19" .
#
# NFL:2 a Schema:SportsTeam ;
#     Schema:name "Atlanta Falcons" ;
#     Schema:sport "American Football" ;
#     NFL:id "2" .
#
# NFL:20 a Schema:SportsTeam ;
#     Schema:name "New Orleans Saints" ;
#     Schema:sport "American Football" ;
#     NFL:id "20" .
#
# NFL:21 a Schema:SportsTeam ;
#     Schema:name "New York Giants" ;
#     Schema:sport "American Football" ;
#     NFL:id "21" .
#
# NFL:22 a Schema:SportsTeam ;
#     Schema:name "New York Jets" ;
#     Schema:sport "American Football" ;
#     NFL:id "22" .
#
# NFL:23 a Schema:SportsTeam ;
#     Schema:name "Oakland Raiders" ;
#     Schema:sport "American Football" ;
#     NFL:id "23" .
#
# NFL:24 a Schema:SportsTeam ;
#     Schema:name "Philadelphia Eagles" ;
#     Schema:sport "American Football" ;
#     NFL:id "24" .
#
# NFL:2495275 a Schema:athlete ;
#     Schema:birthDate "5/28/1989" ;
#     Schema:familyName "Dell" ;
#     Schema:givenName " Mark" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "2011"^^xsd:int,
#         "2012"^^xsd:int .
#
# NFL:2495605 a Schema:athlete ;
#     Schema:birthDate "2/6/1984" ;
#     Schema:familyName "Frampton" ;
#     Schema:givenName " Eric" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:year_played "2007"^^xsd:int,
#         "2008"^^xsd:int,
#         "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int,
#         "2012"^^xsd:int,
#         "2013"^^xsd:int .
#
# NFL:2495791 a Schema:athlete ;
#     Schema:birthDate "12/4/1983" ;
#     Schema:familyName "Zabransky" ;
#     Schema:givenName " Jared" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2007"^^xsd:int .
#
# NFL:2495809 a Schema:athlete ;
#     Schema:birthDate "10/27/1984" ;
#     Schema:familyName "Blackmon" ;
#     Schema:givenName " Will" ;
#     NFL:experience "11"^^xsd:int ;
#     NFL:year_played "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:2499376 a Schema:athlete ;
#     Schema:birthDate "12/27/1973" ;
#     Schema:familyName "Alderson" ;
#     Schema:givenName " Winston" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1997"^^xsd:int .
#
# NFL:2499510 a Schema:athlete ;
#     Schema:birthDate "12/15/1964" ;
#     Schema:familyName "Ball" ;
#     Schema:givenName " Jerry" ;
#     NFL:experience "13"^^xsd:int ;
#     NFL:year_played "1987"^^xsd:int,
#         "1988"^^xsd:int,
#         "1989"^^xsd:int,
#         "1990"^^xsd:int,
#         "1991"^^xsd:int,
#         "1992"^^xsd:int,
#         "1993"^^xsd:int,
#         "1994"^^xsd:int,
#         "1995"^^xsd:int,
#         "1996"^^xsd:int,
#         "1997"^^xsd:int,
#         "1998"^^xsd:int,
#         "1999"^^xsd:int .
#
# NFL:25 a Schema:SportsTeam ;
#     Schema:name "Pittsburgh Steelers" ;
#     Schema:sport "American Football" ;
#     NFL:id "25" .
#
# NFL:2500357 a Schema:athlete ;
#     Schema:birthDate "12/1/1969" ;
#     Schema:familyName "Dees" ;
#     Schema:givenName " Andre" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1992"^^xsd:int .
#
# NFL:2500408 a Schema:athlete ;
#     Schema:birthDate "10/11/1969" ;
#     Schema:familyName "Dixon" ;
#     Schema:givenName " Cal" ;
#     NFL:experience "5"^^xsd:int ;
#     NFL:year_played "1992"^^xsd:int,
#         "1993"^^xsd:int,
#         "1994"^^xsd:int,
#         "1995"^^xsd:int,
#         "1996"^^xsd:int .
#
# NFL:2500536 a Schema:athlete ;
#     Schema:birthDate "10/13/1975" ;
#     Schema:familyName "Ellis" ;
#     Schema:givenName " Ed" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1997"^^xsd:int,
#         "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int .
#
# NFL:2501842 a Schema:athlete ;
#     Schema:birthDate "9/2/1971" ;
#     Schema:familyName "Maddox" ;
#     Schema:givenName " Tommy" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:year_played "1992"^^xsd:int,
#         "1993"^^xsd:int,
#         "1994"^^xsd:int,
#         "1995"^^xsd:int,
#         "1996"^^xsd:int,
#         "1997"^^xsd:int,
#         "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int .
#
# NFL:2502600 a Schema:athlete ;
#     Schema:birthDate "6/29/1977" ;
#     Schema:familyName "Reagor" ;
#     Schema:givenName " Montae" ;
#     NFL:experience "10"^^xsd:int ;
#     NFL:year_played "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2502679 a Schema:athlete ;
#     Schema:birthDate "1/7/1962" ;
#     Schema:familyName "Rivera" ;
#     Schema:givenName " Ron" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:year_played "1984"^^xsd:int,
#         "1985"^^xsd:int,
#         "1986"^^xsd:int,
#         "1987"^^xsd:int,
#         "1988"^^xsd:int,
#         "1989"^^xsd:int,
#         "1990"^^xsd:int,
#         "1991"^^xsd:int,
#         "1992"^^xsd:int .
#
# NFL:2503464 a Schema:athlete ;
#     Schema:birthDate "6/14/1963" ;
#     Schema:familyName "Verdin" ;
#     Schema:givenName " Clarence" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:year_played "1986"^^xsd:int,
#         "1987"^^xsd:int,
#         "1988"^^xsd:int,
#         "1989"^^xsd:int,
#         "1990"^^xsd:int,
#         "1991"^^xsd:int,
#         "1992"^^xsd:int,
#         "1993"^^xsd:int,
#         "1994"^^xsd:int .
#
# NFL:2503572 a Schema:athlete ;
#     Schema:birthDate "4/12/1974" ;
#     Schema:familyName "Weary" ;
#     Schema:givenName " Fred" ;
#     NFL:experience "6"^^xsd:int ;
#     NFL:year_played "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int .
#
# NFL:2504264 a Schema:athlete ;
#     Schema:birthDate "9/8/1977" ;
#     Schema:familyName "Webster" ;
#     Schema:givenName " Jason" ;
#     NFL:experience "9"^^xsd:int ;
#     NFL:year_played "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2504395 a Schema:athlete ;
#     Schema:birthDate "5/17/1978" ;
#     Schema:familyName "Baker" ;
#     Schema:givenName " Jason" ;
#     NFL:experience "11"^^xsd:int ;
#     NFL:year_played "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int,
#         "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int .
#
# NFL:2504656 a Schema:athlete ;
#     Schema:birthDate "9/6/1978" ;
#     Schema:familyName "Tafoya" ;
#     Schema:givenName " Joe" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:year_played "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2505404 a Schema:athlete ;
#     Schema:birthDate "9/12/1980" ;
#     Schema:familyName "Davis" ;
#     Schema:givenName " Jason" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2003"^^xsd:int,
#         "2004"^^xsd:int,
#         "2005"^^xsd:int,
#         "2006"^^xsd:int .
#
# NFL:2506142 a Schema:athlete ;
#     Schema:birthDate "3/3/1983" ;
#     Schema:familyName "Wallace" ;
#     Schema:givenName " Kyle" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2005"^^xsd:int .
#
# NFL:2506362 a Schema:athlete ;
#     Schema:birthDate "6/9/1983" ;
#     Schema:familyName "Washington" ;
#     Schema:givenName " Fabian" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:year_played "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int,
#         "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int .
#
# NFL:2506538 a Schema:athlete ;
#     Schema:birthDate "2/9/1982" ;
#     Schema:familyName "Johnson" ;
#     Schema:givenName " Derrick" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2005"^^xsd:int,
#         "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2506618 a Schema:athlete ;
#     Schema:birthDate "11/11/1982" ;
#     Schema:familyName "Carrington" ;
#     Schema:givenName " Paul" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2006"^^xsd:int,
#         "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2507062 a Schema:athlete ;
#     Schema:birthDate "5/5/1984" ;
#     Schema:familyName "Ghee" ;
#     Schema:givenName " Patrick" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2007"^^xsd:int,
#         "2008"^^xsd:int .
#
# NFL:2507719 a Schema:athlete ;
#     Schema:birthDate "9/4/1986" ;
#     Schema:familyName "Randolph" ;
#     Schema:givenName " Dane" ;
#     NFL:experience "0"^^xsd:int ;
#     NFL:year_played "2009"^^xsd:int .
#
# NFL:2507748 a Schema:athlete ;
#     Schema:birthDate "11/17/1985" ;
#     Schema:familyName "Goldberg" ;
#     Schema:givenName " Cameron" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2009"^^xsd:int .
#
# NFL:2508043 a Schema:athlete ;
#     Schema:birthDate "11/30/1987" ;
#     Schema:familyName "Allen" ;
#     Schema:givenName " Nate" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int .
#
# NFL:2508100 a Schema:athlete ;
#     Schema:birthDate "8/21/1984" ;
#     Schema:familyName "Scaccia" ;
#     Schema:givenName " Fabrizio" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2010"^^xsd:int,
#         "2011"^^xsd:int .
#
# NFL:2508869 a Schema:athlete ;
#     Schema:birthDate "7/30/1937" ;
#     Schema:familyName "Baker" ;
#     Schema:givenName " Dave" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1959"^^xsd:int,
#         "1960"^^xsd:int,
#         "1961"^^xsd:int .
#
# NFL:2509130 a Schema:athlete ;
#     Schema:birthDate "1/21/1939" ;
#     Schema:familyName "Bass" ;
#     Schema:givenName " Norm" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1964"^^xsd:int .
#
# NFL:2509286 a Schema:athlete ;
#     Schema:birthDate "2/9/1896" ;
#     Schema:familyName "Beckwith" ;
#     Schema:givenName " Norm" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1920"^^xsd:int .
#
# NFL:2509361 a Schema:athlete ;
#     Schema:birthDate "6/14/1957" ;
#     Schema:familyName "Bell" ;
#     Schema:givenName " Mark" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:2510942 a Schema:athlete ;
#     Schema:birthDate "6/4/1921" ;
#     Schema:familyName "Calligaro" ;
#     Schema:givenName " Len" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1944"^^xsd:int .
#
# NFL:2512416 a Schema:athlete ;
#     Schema:birthDate "3/3/1943" ;
#     Schema:familyName "D'Amato" ;
#     Schema:givenName " Mike" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1968"^^xsd:int .
#
# NFL:2512457 a Schema:athlete ;
#     Schema:birthDate "9/14/1954" ;
#     Schema:familyName "Darby" ;
#     Schema:givenName " Al" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int .
#
# NFL:2512597 a Schema:athlete ;
#     Schema:birthDate "1/21/1953" ;
#     Schema:familyName "Davis" ;
#     Schema:givenName " Tony" ;
#     NFL:experience "6"^^xsd:int ;
#     NFL:year_played "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:2512778 a Schema:athlete ;
#     Schema:birthDate "12/1/1950" ;
#     Schema:familyName "Demory" ;
#     Schema:givenName " Bill" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1973"^^xsd:int,
#         "1974"^^xsd:int .
#
# NFL:2512828 a Schema:athlete ;
#     Schema:birthDate "1/15/1967" ;
#     Schema:familyName "DeRiggi" ;
#     Schema:givenName " Fred" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1990"^^xsd:int .
#
# NFL:2513563 a Schema:athlete ;
#     Schema:birthDate "4/23/1959" ;
#     Schema:familyName "Elliott" ;
#     Schema:givenName " Tony" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:year_played "1982"^^xsd:int,
#         "1983"^^xsd:int,
#         "1984"^^xsd:int,
#         "1985"^^xsd:int,
#         "1986"^^xsd:int,
#         "1987"^^xsd:int,
#         "1988"^^xsd:int .
#
# NFL:2513736 a Schema:athlete ;
#     Schema:birthDate "5/23/1921" ;
#     Schema:familyName "Evans" ;
#     Schema:givenName " Fred" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1946"^^xsd:int,
#         "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2513861 a Schema:athlete ;
#     Schema:birthDate "9/16/1920" ;
#     Schema:familyName "Farris" ;
#     Schema:givenName " Tom" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1946"^^xsd:int,
#         "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2514196 a Schema:athlete ;
#     Schema:birthDate "5/30/1958" ;
#     Schema:familyName "Foley" ;
#     Schema:givenName " Tim" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1981"^^xsd:int .
#
# NFL:2514211 a Schema:athlete ;
#     Schema:birthDate "2/17/1939" ;
#     Schema:familyName "Fontes" ;
#     Schema:givenName " Wayne" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1962"^^xsd:int .
#
# NFL:2514295 a Schema:athlete ;
#     Schema:birthDate "9/11/1960" ;
#     Schema:familyName "Fowler" ;
#     Schema:givenName " Bobby" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1985"^^xsd:int .
#
# NFL:2514537 a Schema:athlete ;
#     Schema:birthDate "6/21/1929" ;
#     Schema:familyName "Gain" ;
#     Schema:givenName " Bob" ;
#     NFL:experience "12"^^xsd:int ;
#     NFL:year_played "1952"^^xsd:int,
#         "1953"^^xsd:int,
#         "1954"^^xsd:int,
#         "1955"^^xsd:int,
#         "1956"^^xsd:int,
#         "1957"^^xsd:int,
#         "1958"^^xsd:int,
#         "1959"^^xsd:int,
#         "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int .
#
# NFL:2514740 a Schema:athlete ;
#     Schema:birthDate "9/12/1924" ;
#     Schema:familyName "Gehrke" ;
#     Schema:givenName " Bruce" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1948"^^xsd:int .
#
# NFL:2515030 a Schema:athlete ;
#     Schema:birthDate "2/23/1919" ;
#     Schema:familyName "Gonda" ;
#     Schema:givenName " George" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1942"^^xsd:int .
#
# NFL:2515842 a Schema:athlete ;
#     Schema:birthDate "10/30/1965" ;
#     Schema:familyName "Harkey" ;
#     Schema:givenName " Lance" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1987"^^xsd:int .
#
# NFL:2517709 a Schema:athlete ;
#     Schema:birthDate "4/19/1909" ;
#     Schema:familyName "Johnson" ;
#     Schema:givenName " Lorne" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1934"^^xsd:int .
#
# NFL:2518101 a Schema:athlete ;
#     Schema:birthDate "5/29/1983" ;
#     Schema:familyName "Kaleita" ;
#     Schema:givenName " Tom" ;
#     NFL:experience "0"^^xsd:int ;
#     NFL:year_played "2006"^^xsd:int .
#
# NFL:2518471 a Schema:athlete ;
#     Schema:birthDate "9/16/1950" ;
#     Schema:familyName "Kindle" ;
#     Schema:givenName " Greg" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:year_played "1974"^^xsd:int,
#         "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int .
#
# NFL:2518652 a Schema:athlete ;
#     Schema:birthDate "3/19/1919" ;
#     Schema:familyName "Knolla" ;
#     Schema:givenName " Johnny" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1942"^^xsd:int,
#         "1943"^^xsd:int,
#         "1944"^^xsd:int,
#         "1945"^^xsd:int .
#
# NFL:2519112 a Schema:athlete ;
#     Schema:birthDate "10/7/1953" ;
#     Schema:familyName "Larson" ;
#     Schema:givenName " Bill" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:year_played "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int .
#
# NFL:2519453 a Schema:athlete ;
#     Schema:birthDate "1/23/1936" ;
#     Schema:familyName "Lewis" ;
#     Schema:givenName " Joe" ;
#     NFL:experience "5"^^xsd:int ;
#     NFL:year_played "1958"^^xsd:int,
#         "1959"^^xsd:int,
#         "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int .
#
# NFL:2519456 a Schema:athlete ;
#     Schema:birthDate "4/26/1980" ;
#     Schema:familyName "Lewis" ;
#     Schema:givenName " Kevin" ;
#     NFL:experience "0"^^xsd:int ;
#     NFL:year_played "2006"^^xsd:int .
#
# NFL:2520035 a Schema:athlete ;
#     Schema:birthDate "6/18/1910" ;
#     Schema:familyName "Malone" ;
#     Schema:givenName " Chuck" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1934"^^xsd:int,
#         "1935"^^xsd:int,
#         "1936"^^xsd:int,
#         "1937"^^xsd:int,
#         "1938"^^xsd:int,
#         "1939"^^xsd:int,
#         "1940"^^xsd:int,
#         "1941"^^xsd:int,
#         "1942"^^xsd:int .
#
# NFL:2520333 a Schema:athlete ;
#     Schema:birthDate "12/10/1938" ;
#     Schema:familyName "Mathis" ;
#     Schema:givenName " Bill" ;
#     NFL:experience "10"^^xsd:int ;
#     NFL:year_played "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int,
#         "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int .
#
# NFL:2522114 a Schema:athlete ;
#     Schema:birthDate "11/23/1909" ;
#     Schema:familyName "Nichelini" ;
#     Schema:givenName " Al" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1935"^^xsd:int,
#         "1936"^^xsd:int .
#
# NFL:2522592 a Schema:athlete ;
#     Schema:birthDate "12/8/1943" ;
#     Schema:familyName "Otto" ;
#     Schema:givenName " Gus" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int,
#         "1970"^^xsd:int,
#         "1971"^^xsd:int,
#         "1972"^^xsd:int .
#
# NFL:2523136 a Schema:athlete ;
#     Schema:birthDate "9/11/1892" ;
#     Schema:familyName "Petty" ;
#     Schema:givenName " Ross" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1920"^^xsd:int .
#
# NFL:2523147 a Schema:athlete ;
#     Schema:birthDate "7/31/1947" ;
#     Schema:familyName "Pharr" ;
#     Schema:givenName " Tommy" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1970"^^xsd:int .
#
# NFL:2523695 a Schema:athlete ;
#     Schema:birthDate "2/10/1961" ;
#     Schema:familyName "Raglin" ;
#     Schema:givenName " Floyd" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1987"^^xsd:int .
#
# NFL:2523700 a Schema:athlete ;
#     Schema:birthDate "12/21/1930" ;
#     Schema:familyName "Raiff" ;
#     Schema:givenName " Jim" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1954"^^xsd:int .
#
# NFL:2523928 a Schema:athlete ;
#     Schema:birthDate "9/14/1927" ;
#     Schema:familyName "Reid" ;
#     Schema:givenName " Breezy" ;
#     NFL:experience "7"^^xsd:int ;
#     NFL:year_played "1950"^^xsd:int,
#         "1951"^^xsd:int,
#         "1952"^^xsd:int,
#         "1953"^^xsd:int,
#         "1954"^^xsd:int,
#         "1955"^^xsd:int,
#         "1956"^^xsd:int .
#
# NFL:2524829 a Schema:athlete ;
#     Schema:birthDate "7/7/1956" ;
#     Schema:familyName "Sampson" ;
#     Schema:givenName " Howard" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1978"^^xsd:int,
#         "1979"^^xsd:int .
#
# NFL:2524989 a Schema:athlete ;
#     Schema:birthDate "8/12/1930" ;
#     Schema:familyName "Scarbath" ;
#     Schema:givenName " Jack" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1953"^^xsd:int,
#         "1954"^^xsd:int,
#         "1955"^^xsd:int,
#         "1956"^^xsd:int .
#
# NFL:2525128 a Schema:athlete ;
#     Schema:birthDate "10/18/1922" ;
#     Schema:familyName "Schuler" ;
#     Schema:givenName " Bill" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2525255 a Schema:athlete ;
#     Schema:birthDate "5/16/1960" ;
#     Schema:familyName "Sealby" ;
#     Schema:givenName " Randy" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1987"^^xsd:int .
#
# NFL:2525335 a Schema:athlete ;
#     Schema:birthDate "5/22/1918" ;
#     Schema:familyName "Sergienko" ;
#     Schema:givenName " George" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:year_played "1943"^^xsd:int,
#         "1944"^^xsd:int,
#         "1945"^^xsd:int,
#         "1946"^^xsd:int .
#
# NFL:2527011 a Schema:athlete ;
#     Schema:birthDate "3/8/1945" ;
#     Schema:familyName "Tanner" ;
#     Schema:givenName " John" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1971"^^xsd:int,
#         "1972"^^xsd:int,
#         "1973"^^xsd:int,
#         "1974"^^xsd:int .
#
# NFL:2527085 a Schema:athlete ;
#     Schema:birthDate "10/23/1958" ;
#     Schema:familyName "Taylor" ;
#     Schema:givenName " Greg" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1982"^^xsd:int .
#
# NFL:2527193 a Schema:athlete ;
#     Schema:birthDate "1/11/1949" ;
#     Schema:familyName "Thaxton" ;
#     Schema:givenName " Jim" ;
#     NFL:experience "5"^^xsd:int ;
#     NFL:year_played "1973"^^xsd:int,
#         "1974"^^xsd:int,
#         "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int .
#
# NFL:2527241 a Schema:athlete ;
#     Schema:birthDate "9/1/1942" ;
#     Schema:familyName "Thomas" ;
#     Schema:givenName " Gene" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int .
#
# NFL:2527303 a Schema:athlete ;
#     Schema:birthDate "" ;
#     Schema:familyName "Thompson" ;
#     Schema:givenName " Pinky" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1927"^^xsd:int .
#
# NFL:2530581 a Schema:athlete ;
#     Schema:birthDate "9/12/1988" ;
#     Schema:familyName "Hall" ;
#     Schema:givenName " Bryan" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2011"^^xsd:int,
#         "2012"^^xsd:int,
#         "2013"^^xsd:int .
#
# NFL:2530729 a Schema:athlete ;
#     Schema:birthDate "10/25/1987" ;
#     Schema:familyName "Riley" ;
#     Schema:givenName " Chris" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2011"^^xsd:int,
#         "2012"^^xsd:int .
#
# NFL:2530849 a Schema:athlete ;
#     Schema:birthDate "2/18/1987" ;
#     Schema:familyName "Lewis" ;
#     Schema:givenName " Andrew" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2011"^^xsd:int .
#
# NFL:2532782 a Schema:athlete ;
#     Schema:birthDate "11/22/1989" ;
#     Schema:familyName "Adams" ;
#     Schema:givenName " Joe" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2012"^^xsd:int,
#         "2013"^^xsd:int,
#         "2014"^^xsd:int .
#
# NFL:2532877 a Schema:athlete ;
#     Schema:birthDate "1/1/1990" ;
#     Schema:familyName "Johnson" ;
#     Schema:givenName " Trumaine" ;
#     NFL:experience "6"^^xsd:int ;
#     NFL:year_played "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int,
#         "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int .
#
# NFL:2539307 a Schema:athlete ;
#     Schema:birthDate "1/19/1990" ;
#     Schema:familyName "Holmes" ;
#     Schema:givenName " Khaled" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "1973"^^xsd:int,
#         "1974"^^xsd:int,
#         "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int .
#
# NFL:2541703 a Schema:athlete ;
#     Schema:birthDate "7/12/1991" ;
#     Schema:familyName "Eubanks" ;
#     Schema:givenName " Darius" ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2013"^^xsd:int,
#         "2014"^^xsd:int,
#         "2015"^^xsd:int .
#
# NFL:2541732 a Schema:athlete ;
#     Schema:birthDate "2/15/1990" ;
#     Schema:familyName "Nady" ;
#     Schema:givenName " Jeff" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2013"^^xsd:int .
#
# NFL:2541971 a Schema:athlete ;
#     Schema:birthDate "5/3/1990" ;
#     Schema:familyName "Castillo" ;
#     Schema:givenName " Greg" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2013"^^xsd:int .
#
# NFL:2543640 a Schema:athlete ;
#     Schema:birthDate "4/26/1990" ;
#     Schema:familyName "Savage" ;
#     Schema:givenName " Tom" ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:year_played "2009"^^xsd:int .
#
# NFL:2550164 a Schema:athlete ;
#     Schema:birthDate "7/28/1990" ;
#     Schema:familyName "Carrie" ;
#     Schema:givenName " T.J." ;
#     NFL:experience "4"^^xsd:int ;
#     NFL:year_played "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int .
#
# NFL:2550652 a Schema:athlete ;
#     Schema:birthDate "1/24/1991" ;
#     Schema:familyName "James" ;
#     Schema:givenName " Waymon" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "2014"^^xsd:int .
#
# NFL:2552444 a Schema:athlete ;
#     Schema:birthDate "3/31/1992" ;
#     Schema:familyName "Walton" ;
#     Schema:givenName " L.T." ;
#     NFL:experience "3"^^xsd:int ;
#     NFL:year_played "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int,
#         "2012"^^xsd:int,
#         "2013"^^xsd:int .
#
# NFL:2553790 a Schema:athlete ;
#     Schema:birthDate "1/15/1993" ;
#     Schema:familyName "Bausby" ;
#     Schema:givenName " DeVante" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "2009"^^xsd:int .
#
# NFL:2553801 a Schema:athlete ;
#     Schema:birthDate "3/11/1992" ;
#     Schema:familyName "Garner" ;
#     Schema:givenName " Manasseh" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1973"^^xsd:int,
#         "1974"^^xsd:int .
#
# NFL:2555201 a Schema:athlete ;
#     Schema:birthDate "8/2/1994" ;
#     Schema:familyName "Tunsil" ;
#     Schema:givenName " Laremy" ;
#     NFL:experience "2"^^xsd:int ;
#     NFL:year_played "1974"^^xsd:int,
#         "1975"^^xsd:int,
#         "1976"^^xsd:int,
#         "1977"^^xsd:int .
#
# NFL:2556677 a Schema:athlete ;
#     Schema:birthDate "12/4/1992" ;
#     Schema:familyName "Seau" ;
#     Schema:givenName " Ian" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:2557450 a Schema:athlete ;
#     Schema:birthDate "5/5/1993" ;
#     Schema:familyName "Williams" ;
#     Schema:givenName " Isaiah" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1997"^^xsd:int,
#         "1998"^^xsd:int,
#         "1999"^^xsd:int,
#         "2000"^^xsd:int,
#         "2001"^^xsd:int,
#         "2002"^^xsd:int,
#         "2003"^^xsd:int,
#         "2004"^^xsd:int .
#
# NFL:2557873 a Schema:athlete ;
#     Schema:birthDate "5/29/1994" ;
#     Schema:familyName "Feeney" ;
#     Schema:givenName " Dan" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int,
#         "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int .
#
# NFL:2557885 a Schema:athlete ;
#     Schema:birthDate "1/31/1995" ;
#     Schema:familyName "Leggett" ;
#     Schema:givenName " Jordan" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1946"^^xsd:int,
#         "1947"^^xsd:int,
#         "1948"^^xsd:int .
#
# NFL:2558860 a Schema:athlete ;
#     Schema:birthDate "" ;
#     Schema:familyName "Williams" ;
#     Schema:givenName " Marquez" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1934"^^xsd:int,
#         "1935"^^xsd:int,
#         "1936"^^xsd:int,
#         "1937"^^xsd:int,
#         "1938"^^xsd:int,
#         "1939"^^xsd:int,
#         "1940"^^xsd:int,
#         "1941"^^xsd:int,
#         "1942"^^xsd:int .
#
# NFL:2559295 a Schema:athlete ;
#     Schema:birthDate "" ;
#     Schema:familyName "Wilkinson" ;
#     Schema:givenName " Elijah" ;
#     NFL:experience "1"^^xsd:int ;
#     NFL:year_played "1942"^^xsd:int,
#         "1943"^^xsd:int,
#         "1944"^^xsd:int,
#         "1945"^^xsd:int .
#
# NFL:26 a Schema:SportsTeam ;
#     Schema:name "Los Angeles Chargers" ;
#     Schema:sport "American Football" ;
#     NFL:id "26" .
#
# NFL:27 a Schema:SportsTeam ;
#     Schema:name "San Francisco 49ers" ;
#     Schema:sport "American Football" ;
#     NFL:id "27" .
#
# NFL:28 a Schema:SportsTeam ;
#     Schema:name "Seattle Seahawks" ;
#     Schema:sport "American Football" ;
#     NFL:id "28" .
#
# NFL:29 a Schema:SportsTeam ;
#     Schema:name "Los Angeles Rams" ;
#     Schema:sport "American Football" ;
#     NFL:id "29" .
#
# NFL:3 a Schema:SportsTeam ;
#     Schema:name "Baltimore Ravens" ;
#     Schema:sport "American Football" ;
#     NFL:id "3" .
#
# NFL:30 a Schema:SportsTeam ;
#     Schema:name "Tampa Bay Buccaneers" ;
#     Schema:sport "American Football" ;
#     NFL:id "30" .
#
# NFL:31 a Schema:SportsTeam ;
#     Schema:name "Tennessee Titans" ;
#     Schema:sport "American Football" ;
#     NFL:id "31" .
#
# NFL:32 a Schema:SportsTeam ;
#     Schema:name "Washington Redskins" ;
#     Schema:sport "American Football" ;
#     NFL:id "32" .
#
# NFL:4 a Schema:SportsTeam ;
#     Schema:name "Buffalo Bills" ;
#     Schema:sport "American Football" ;
#     NFL:id "4" .
#
# NFL:494261 a Schema:athlete ;
#     Schema:birthDate "4/1/1988" ;
#     Schema:familyName "Coleman" ;
#     Schema:givenName " Kurt" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1964"^^xsd:int .
#
# NFL:496949 a Schema:athlete ;
#     Schema:birthDate "5/3/1988" ;
#     Schema:familyName "Riley" ;
#     Schema:givenName " Perry" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1976"^^xsd:int,
#         "1977"^^xsd:int,
#         "1978"^^xsd:int,
#         "1979"^^xsd:int,
#         "1980"^^xsd:int,
#         "1981"^^xsd:int .
#
# NFL:496980 a Schema:athlete ;
#     Schema:birthDate "11/19/1986" ;
#     Schema:familyName "Beadles" ;
#     Schema:givenName " Zane" ;
#     NFL:experience "8"^^xsd:int ;
#     NFL:year_played "1960"^^xsd:int,
#         "1961"^^xsd:int,
#         "1962"^^xsd:int,
#         "1963"^^xsd:int,
#         "1964"^^xsd:int,
#         "1965"^^xsd:int,
#         "1966"^^xsd:int,
#         "1967"^^xsd:int,
#         "1968"^^xsd:int,
#         "1969"^^xsd:int .
#
# NFL:5 a Schema:SportsTeam ;
#     Schema:name "Carolina Panthers" ;
#     Schema:sport "American Football" ;
#     NFL:id "5" .
#
# NFL:6 a Schema:SportsTeam ;
#     Schema:name "Chicago Bears" ;
#     Schema:sport "American Football" ;
#     NFL:id "6" .
#
# NFL:7 a Schema:SportsTeam ;
#     Schema:name "Cincinnati Bengals" ;
#     Schema:sport "American Football" ;
#     NFL:id "7" .
#
# NFL:79593 a Schema:athlete ;
#     Schema:birthDate "9/30/1986" ;
#     Schema:familyName "Johnson" ;
#     Schema:givenName " Quinn" ;
#     NFL:experience "5"^^xsd:int ;
#     NFL:year_played "2009"^^xsd:int,
#         "2010"^^xsd:int,
#         "2011"^^xsd:int,
#         "2012"^^xsd:int,
#         "2013"^^xsd:int .
#
# NFL:8 a Schema:SportsTeam ;
#     Schema:name "Cleveland Browns" ;
#     Schema:sport "American Football" ;
#     NFL:id "8" .
#
# NFL:9 a Schema:SportsTeam ;
#     Schema:name "Dallas Cowboys" ;
#     Schema:sport "American Football" ;
#     NFL:id "9" .

# %%
qres = dados.query(
    """SELECT ?id
       WHERE {
          # ?p a Schema:SportsTeam .
          # ?p NFL:id ?id.
          # ?p Schema:name "Hoston Texans"
       }LIMIT 50""")
for row in qres:
    print("%s " % row)

# %%
    q = prepareQuery(
     """SELECT ?id
       WHERE {
          # ?p a Schema:SportsTeam .
          # ?p NFL:id ?id.
          # ?p Schema:name ?name
       }LIMIT 50""")

    for row in dados.query(q, initBindings={"name": "Houston Texans"}):
     print(row)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-1044-02fb2f13e73e> in <module>
# ----> 1 q = prepareQuery(
#       2  """SELECT ?id
#       3    WHERE {
#       4       ?p a Schema:SportsTeam .
#       5       ?p NFL:id ?id.
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\processor.py in prepareQuery(queryString, initNs, base)
#      24     Parse and translate a SPARQL Query
#      25     """
# ---> 26     ret = translateQuery(parseQuery(queryString), base, initNs)
#      27     ret._original_args = (queryString, initNs, base)
#      28     return ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in translateQuery(q, base, initNs)
#     761
#     762     # absolutize/resolve prefixes
# --> 763     q[1] = traverse(
#     764         q[1], visitPost=functools.partial(translatePName, prologue=prologue))
#     765
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in traverse(tree, visitPre, visitPost, complete)
#     383     """
#     384     try:
# --> 385         r = _traverse(tree, visitPre, visitPost)
#     386         if complete is not None:
#     387             return complete
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     344     elif isinstance(e, CompValue):
#     345         for k, val in e.items():
# --> 346             e[k] = _traverse(val, visitPre, visitPost)
#     347
#     348     _e = visitPost(e)
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     344     elif isinstance(e, CompValue):
#     345         for k, val in e.items():
# --> 346             e[k] = _traverse(val, visitPre, visitPost)
#     347
#     348     _e = visitPost(e)
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     338
#     339     if isinstance(e, (list, ParseResults)):
# --> 340         return [_traverse(x, visitPre, visitPost) for x in e]
#     341     elif isinstance(e, tuple):
#     342         return tuple([_traverse(x, visitPre, visitPost) for x in e])
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     338
#     339     if isinstance(e, (list, ParseResults)):
# --> 340         return [_traverse(x, visitPre, visitPost) for x in e]
#     341     elif isinstance(e, tuple):
#     342         return tuple([_traverse(x, visitPre, visitPost) for x in e])
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     344     elif isinstance(e, CompValue):
#     345         for k, val in e.items():
# --> 346             e[k] = _traverse(val, visitPre, visitPost)
#     347
#     348     _e = visitPost(e)
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     338
#     339     if isinstance(e, (list, ParseResults)):
# --> 340         return [_traverse(x, visitPre, visitPost) for x in e]
#     341     elif isinstance(e, tuple):
#     342         return tuple([_traverse(x, visitPre, visitPost) for x in e])
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     338
#     339     if isinstance(e, (list, ParseResults)):
# --> 340         return [_traverse(x, visitPre, visitPost) for x in e]
#     341     elif isinstance(e, tuple):
#     342         return tuple([_traverse(x, visitPre, visitPost) for x in e])
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     338
#     339     if isinstance(e, (list, ParseResults)):
# --> 340         return [_traverse(x, visitPre, visitPost) for x in e]
#     341     elif isinstance(e, tuple):
#     342         return tuple([_traverse(x, visitPre, visitPost) for x in e])
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in <listcomp>(.0)
#     338
#     339     if isinstance(e, (list, ParseResults)):
# --> 340         return [_traverse(x, visitPre, visitPost) for x in e]
#     341     elif isinstance(e, tuple):
#     342         return tuple([_traverse(x, visitPre, visitPost) for x in e])
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in _traverse(e, visitPre, visitPost)
#     346             e[k] = _traverse(val, visitPre, visitPost)
#     347
# --> 348     _e = visitPost(e)
#     349     if _e is not None:
#     350         return _e
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\algebra.py in translatePName(p, prologue)
#     144     if isinstance(p, CompValue):
#     145         if p.name == 'pname':
# --> 146             return prologue.absolutize(p)
#     147         if p.name == 'literal':
#     148             return Literal(p.string, lang=p.lang,
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\sparql.py in absolutize(self, iri)
#     390         if isinstance(iri, CompValue):
#     391             if iri.name == 'pname':
# --> 392                 return self.resolvePName(iri.prefix, iri.localname)
#     393             if iri.name == 'literal':
#     394                 return Literal(
#
# C:\ProgramData\Anaconda3\lib\site-packages\rdflib\plugins\sparql\sparql.py in resolvePName(self, prefix, localname)
#     374         ns = self.namespace_manager.store.namespace(prefix or "")
#     375         if ns is None:
# --> 376             raise Exception('Unknown namespace prefix : %s' % prefix)
#     377         return URIRef(ns + (localname or ""))
#     378
#
# Exception: Unknown namespace prefix : Schema
